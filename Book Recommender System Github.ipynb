# %% [markdown]
# # Framing the Problem

# %% [markdown]
# With the emergence of Machine Learning and AI, we are now able to utilize big data at a level that we could have never previously imagined. However, despite all these tools that are available at our disposal, it is still important on how we apply the data in a business context and how we make the most out of it.
#
# For retailers, more specifically book retailers, we can work with these big data using consumer reviewers from that was purchased, and then use those ratings to make recommendations for similar books that interests our consumers for recurring businesses and improved sales.
#
# The dataset that we are using is from **GoodReads**, which is a website that allows users to freely search thier database for books and book reviews.
# <br>
# <br>
#
# **Business Solution:**
# - I will use an user-based Collaborative Filtering model to make predictions and recommend books to consumers
# - The model is also able to determine similar interests of other consumers that we made our predictions and recommendations for
# <br>
# <br>
#
# **Benefits:**
# - Improve marketing strategies
# - Better inventory control for each products
# - Higher sales and revenues
# <br>
# <br>
#
# **Robustness:**
# - We are using the Euclidean Distance Model to determine the similarities between consumers based on all the products that each consumers previously rated
# - The Euclidean Distance Model ensures the closest proximity among users which translate to similar interests among consumers for book ratings
# <br>
# <br>
#
# **Assumptions:**
# - We're assuming that 300K+ samples in our data is sufficient to determine the accuracy of our model for making predictions and recommendations
# - We're assuming that the sample size in our data is similar to the size of a real word data
# <br>
# <br>
#
# **Future:**
# <br>
#
# This model is an introductory model for creating a recommendation system. In the future, I will use Affinity Analysis for recommendations on cross product selling.

# %% [markdown]
# # Data Overview

# %%
import pandas as pd
csv = "br.csv"
df = pd.read_csv(csv, engine='python', error_bad_lines=False)
# use python engine for more feature-complete
# skips error bad line
df.head(5)
# Out:
# Skipping line 312075: unexpected end of data
#    bookID                                              title  \
# 0       9  Unauthorized Harry Potter Book Seven News: "Ha...
# 1       8  Harry Potter Boxed Set, Books 1-5 (Harry Potte...
# 2       3              Harry Potter and the Sorcerer's Stone
# 3       1  Harry Potter and the Half-Blood Prince (Harry ...
# 4       2  Harry Potter and the Order of the Phoenix (Har...
#
#                    author  rating  ratingsCount  reviewsCount  \
# 0  W. Frederick Zimmerman    3.73            22             1
# 1            J.K. Rowling    4.77         34107           156
# 2            J.K. Rowling    4.44       4911929         77741
# 3            J.K. Rowling    4.54       1810404         28053
# 4            J.K. Rowling    4.47       1862749         29308
#
#                 reviewerName  reviewerRatings  \
# 0                  Charles G              3.0
# 1  âœ¿Katherine Elizabethâœ¿              5.0
# 2                       Lora              5.0
# 3          Cait (Paper Fury)              5.0
# 4     Diane ÏŸ [ Lestrange ]              5.0
#
#                                               review
# 0                                                NaN
# 1                                                NaN
# 2  I'm going to keep this brief since there isn't...
# 3  "Read Harry Potter!" they said. "It'll be fun!...
# 4                                                NaN

# %% [markdown]
# Here we see our dataset includes numerous columns, but for the purpose of building our recommendation system, we will only use the following columns:
# - reviewerName
# - title
# - reviewerRatings
#
# <u>Note</u> that there is one line that showed "error bad line" which we will skip, since one row does not have significant impact on the entirety of the 300K+ sample size.

# %%
# filters the items that we need
df = df.filter(items=['reviewerName', 'title', 'reviewerRatings'])
df.head(5)
# Out:
#                 reviewerName  \
# 0                  Charles G
# 1  âœ¿Katherine Elizabethâœ¿
# 2                       Lora
# 3          Cait (Paper Fury)
# 4     Diane ÏŸ [ Lestrange ]
#
#                                                title  reviewerRatings
# 0  Unauthorized Harry Potter Book Seven News: "Ha...              3.0
# 1  Harry Potter Boxed Set, Books 1-5 (Harry Potte...              5.0
# 2              Harry Potter and the Sorcerer's Stone              5.0
# 3  Harry Potter and the Half-Blood Prince (Harry ...              5.0
# 4  Harry Potter and the Order of the Phoenix (Har...              5.0

# %% [markdown]
# ### Data Cleansing

# %% [markdown]
# Now that our dataset is filtered to the columns that we are interested in for our model, we will proceed to cleanse our data by performing the following:
# - Check for missing data
# - Remove all data that has missing values since we cannot make predictions without actual reviewerName, title or reviewerRatings
# - Remove all non-ASCII characters as we see a lot of symbols that we cannot interpret
# - Reset the index of our DataFrame after data cleansing so that all rows are indexed sequentially

# %%
# checks for missing value for each column
for missing in (df['reviewerName'].isnull().value_counts(),
                df['title'].isnull().value_counts(),
                df['reviewerRatings'].isnull().value_counts()):
    print(missing)
# Out:
# False    311532
# True        541
# Name: reviewerName, dtype: int64
# False    312073
# Name: title, dtype: int64
# False    230898
# True      81175
# Name: reviewerRatings, dtype: int64

# %%
# drops missing values for all columns
df = df.dropna(how='any')

# remove rows with non-ASCII characters in reviewerName and title column
df = df[~df.reviewerName.str.contains(r'[^\x00-\x7F]')]
df = df[~df.title.str.contains(r'[^\x00-\x7F]')]

# resets the index
df = df.reset_index(drop=True)

# check and see the cleansed data
df.head(20)
# Out:
#          reviewerName                                              title  \
# 0           Charles G  Unauthorized Harry Potter Book Seven News: "Ha...
# 1                Lora              Harry Potter and the Sorcerer's Stone
# 2   Cait (Paper Fury)  Harry Potter and the Half-Blood Prince (Harry ...
# 3          Jen Holman   The Harry Potter Collection (Harry Potter, #1-6)
# 4                Inge  Harry Potter and the Prisoner of Azkaban (Harr...
# 5              Ashton                   Charlie Oink (Easy Peasy People)
# 6                Rosa  My Country Right or Left: 1940-1943 (The Colle...
# 7            Matthias                                        Why I Write
# 8           Catsalive  Bella Tuscany & Under the Tuscan Sun (2 Book Set)
# 9               Keith                  Selected Poems of Herman Melville
# 10        Kenne Jones  The Senator and the Socialite: The True Story ...
# 11              James               Great Short Works of Herman Melville
# 12          Jay Smith          Vance Packard & American Social Criticism
# 13                Ken                   Redburn, White-Jacket, Moby-Dick
# 14             Mackay                                   Moon Metro Paris
# 15    Anne Hawn Smith  Morality For Beautiful Girls (No. 1 Ladies' De...
# 16    Anne Hawn Smith  Morality for Beautiful Girls (No. 1 Ladies' De...
# 17              Donna  The Good Husband of Zebra Drive (No. 1 Ladies'...
# 18               Kara                                  Paris to the Moon
# 19             Laurel  In the Company of Cheerful Ladies (No. 1 Ladie...
#
#     reviewerRatings
# 0               3.0
# 1               5.0
# 2               5.0
# 3               5.0
# 4               5.0
# 5               5.0
# 6               4.0
# 7               5.0
# 8               1.0
# 9               3.0
# 10              4.0
# 11              5.0
# 12              3.0
# 13              5.0
# 14              3.0
# 15              5.0
# 16              5.0
# 17              5.0
# 18              5.0
# 19              4.0

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# Now that our data is cleansed, we still have a sample size of 217K+ which is large enough to make meaningful recommendations. We also want to analyze our data briefly before feeding the data into our model.

# %%
# see how many times each book comes up rated (calls the collection package)
from collections import Counter
Counter(df['title'].head(20))
# Out:
# Counter({'Unauthorized Harry Potter Book Seven News: "Half-Blood Prince" Analysis and Speculation': 1,
#          "Harry Potter and the Sorcerer's Stone": 1,
#          'Harry Potter and the Half-Blood Prince (Harry Potter, #6)': 1,
#          'The Harry Potter Collection (Harry Potter, #1-6)': 1,
#          'Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)': 1,
#          'Charlie Oink (Easy Peasy People)': 1,
#          'My Country Right or Left: 1940-1943 (The Collected Essays, Journalism & Letters, Vol. 2)': 1,
#          'Why I Write': 1,
#          'Bella Tuscany & Under the Tuscan Sun (2 Book Set)': 1,
#          'Selected Poems of Herman Melville': 1,
#          "The Senator and the Socialite: The True Story of America's First Black Dynasty": 1,
#          'Great Short Works of Herman Melville': 1,
#          'Vance Packard & American Social Criticism': 1,
#          'Redburn, White-Jacket, Moby-Dick': 1,
#          'Moon Metro Paris': 1,
#          "Morality For Beautiful Girls (No. 1 Ladies' Detective Agency)": 1,
#          "Morality for Beautiful Girls (No. 1 Ladies' Detective Agency, #3)": 1,
#          "The Good Husband of Zebra Drive (No. 1 Ladies' Detective Agency, #8)": 1,
#          'Paris to the Moon': 1,
#          "In the Company of Cheerful Ladies (No. 1 Ladies' Detective Agency, #6)": 1})

# %% [markdown]
# Here we see that there are multiple books that got rated multiple times.

# %%
# see how many times multiple reviewers rated the same title
df.groupby("reviewerName")["title"].unique().head(20)
# Out:
# reviewerName
# \tErica                                            [Recuerda Cuerpo...: Poesia Erotica, Ultimate ...
#   LunaBel                                          [Don DeLillo's White Noise (Bloom's Modern Cri...
#  ( A Bald Mage) Keith                                 [Prism of the Night: A Biography of Anne Rice]
#  (shan) Littlebookcove                             [The Wicker Man, The Third Horror (99 Fear Str...
#  - The Book Rack                                   [Arthur C. Clarke: 2001/A Space Odyssey, The C...
#  Aesha                                                    [Intimacy: Trusting Oneself and the Other]
#  Barb Bailey                                       [301 Country Christmas Quilt Blocks, Do-It-You...
#  Caleb                                             [Christopher Davis's Best Year Yet: Hyperion C...
#  Danielle The Book Huntress (Back to the Books)    [Night Embrace (Dark-Hunter, #3), Lucky You, T...
#  Debra (WifeEclectic)                              [Baby Chronicles: My Very Own Story: from pre-...
#  Doris Powell                                                              [Psalms for Zero Gravity]
#  Dr. Michael Galvin                                [God Isn't Here: A Young American's Entry into...
#  Fernando Brito                                    [Front Row Center 2: Inside the World's Greate...
#  Jan  Vajda                                        [John Grisham: A Reader's Checklist and Refere...
#  Jordan                                            [The Day It Rained Hearts, Four Valentines in ...
#  Julie                                                            [Sacra Pagina: The Gospel of Luke]
#  Lady Jayne *~*The Beach Bandida*~*                               [Room Service (Do Not Disturb #6)]
#  Linda (Miss Greedybooks)                          [Detroit Is My Own Home Town, Herbalism: Using...
#  Marla                                                                           [Sheriff Luke Ludd]
#  Martin                                            [Pandora's Box: Pandora's Box, Spawn of Hell, ...
# Name: title, dtype: object

# %% [markdown]
# Here we see that there are not many books that was rated by multiple users.

# %%
# see all the different users rated this one title that have multiple users
same_names = df[df['title'] == 'Anne of Avonlea']["reviewerName"].unique()
for name in same_names:
    print(name)
# Out:
# Maureen

# %% [markdown]
# Based on our analysis so far:
# - First we looked to see if certain books were rated multiple times
# - Then we want to see if these certain books that were rated multiple times have different users that rated them
# - Next we took a book called "Anne of Avonlea" which has 12 ratings, and check to see how many users rated that book
# - Lastly, our result showed that only "Maureen" rated the book "Anne of Avonlea" 12 times
#
# The purpose of our analysis so far was to see if there were two users that rated the same book multiple times, so we can then use those two users and see how close they rank from each other using the Euclidean Distance Model.
#
# Since we were not able to find a book that was rated by two users manually, we will create a function in our model that will find the Euclidean Distance between "Maureen" and other users, and rank their similarities level in comparison to "Maureen" based on similar books that was previously rated.
#
# <u>Note</u>: I have reduced the number of rows of data displayed to 20 rows, since it will take a long time to scroll through the results once the project is uploaded online. As a result, you may not see the "Anne of Avonlea" book displayed in the output above. However, in order to display the full dataset, we just need to remove the .head(20) method in each of the three lines under "Data Cleansing" and "Data Analysis" section.

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# In order to fit our DataFrame to our model, we need to structure the data in this form:
#
#     {
#     reviewerName: { title : reviewerRatings }
#     }
#
# This applies to all books for each user. Once we manipulated the data into our desired structure, we will then transform our DataFrame into a dictionary for our model testing.
#
# To visualize this, below is how we want to show our data.

# %%
# filters the unique reviewerName for their corresponding title and reviewRatings
df1 = df.set_index(['reviewerName', 'title']).sort_index()
df1.head(5)
# Out:
#                                                                  reviewerRatings
# reviewerName title
# \tErica      Recuerda Cuerpo...: Poesia Erotica                              3.0
#              Ultimate Lesbian Erotica 2005                                   3.0
#   LunaBel    Beyond Grief and Nothing: A Reading of Don Delillo              4.0
#              Conversations with Don DeLillo                                  4.0
#              Don DeLillo's White Noise (Bloom's Modern Criti...              3.0

# %%
# converts dataframe to dictionary
d = (df.groupby('reviewerName')['title','reviewerRatings'].apply(lambda x: dict(x.values)).to_dict())
# use groupy with lambda function per reviewerName, then use to_dict to convert from DataFrame to dictionary
d
# Out:
# {'\tErica': {'Recuerda Cuerpo...: Poesia Erotica': 3.0,
#   'Ultimate Lesbian Erotica 2005': 3.0},
#  '  LunaBel ': {"Don DeLillo's White Noise (Bloom's Modern Critical Interpretations)": 3.0,
#   'Hippolytus': 3.0,
#   'Hippolytos': 3.0,
#   'The Hippolytus of Euripides': 3.0,
#   'Conversations with Don DeLillo': 4.0,
#   'Beyond Grief and Nothing: A Reading of Don Delillo': 4.0,
#   'Don DeLillo: The Physics of Language': 5.0,
#   'The Day Room': 4.0,
#   'Reading Simulacra: Fatal Theories for Postmodernity': 3.0,
#   'The Enigma of Health: The Art of Healing in a Scientific Age': 5.0},
#  ' ( A Bald Mage) Keith': {'Prism of the Night: A Biography of Anne Rice': 4.0},
#  ' (shan) Littlebookcove': {'The Wicker Man': 5.0,
#   'The Third Horror (99 Fear Street: The House of Evil, #3)': 3.0},
#  ' - The Book Rack': {'Arthur C. Clarke: 2001/A Space Odyssey, The City And The Stars, The Deep Range, A Fall Of Moondust, Rendevous With Rama': 4.0},
#  ' Aesha ': {'Intimacy: Trusting Oneself and the Other': 3.0},
#  ' Barb Bailey': {'301 Country Christmas Quilt Blocks': 3.0,
#   'Do-It-Yourself Framed Quilts: Fast, Fun & Easy Projects': 4.0,
#   "Don't Call Me Rosie: The Women Who Welded the LSTs and the Men Who Sailed on Them": 3.0,
#   'Exotic Postcards: The Lure of Distant Lands': 5.0,
#   'The Wedding Shower Book; How to plan the perfect celebration-including creative ideas for invitations, games, themes, decorations, gifts, and more': 5.0,
#   "Nana's Gift": 3.0},
#  ' Caleb': {"Christopher Davis's Best Year Yet: Hyperion Chapters; Grade 3": 5.0},
#  ' Danielle The Book Huntress (Back to the Books)': {'Night Embrace (Dark-Hunter, #3)': 3.0,
#   'Lucky You': 4.0,
#   'The Complete Stories of Robert Louis Stevenson: Strange Case of Dr. Jekyll and Mr. Hyde and Nineteen Other Tales': 4.0,
#   'Z for Zachariah': 5.0,
#   'Honor Bound ': 5.0,
#   'Honor Bound (large print edition)': 5.0,
#   'Pacific Vortex (Dirk Pitt, #1)': 3.0,
#   'Half Moon Investigations': 4.0,
#   'From This Moment On (de Piaget, #8; de Piaget/MacLeod, #9)': 5.0,
#   'Strange Case of Dr Jekyll and Mr Hyde and Other Tales': 4.0,
#   'Z For Zachariah': 5.0,
#   'Z for Zachariah. (Lernmaterialien)': 5.0,
#   'Man of My Dreams (includes: The League, #3.5)': 5.0,
#   'Dr. Jekyll and Mr. Hyde & Other Stories': 4.0,
#   'Sun Kissed (Kendrick/Coulter/Harrigan, #7)': 4.0,
#   'A Personal Matter': 5.0,
#   "The Sicilian's Mistress": 4.0,
#   'Dates from Hell': 4.0,
#   'Lord of Scoundrels (Scoundrels, #3)': 5.0,
#   'Die Offensive': 5.0,
#   'Area 7 (Shane Schofield, #2)': 5.0,
#   '100 Hair-Raising Little Horror Stories': 4.0,
#   'The Yellow Sign and Other Stories: The Complete Weird Tales of Robert W. Chambers': 4.0,
#   'A Taste for Blood': 3.0,
#   'Dont Sweat Small Stuff': 5.0,
#   'Dont Sweat The Small Stuff': 5.0,
#   'Touchpoints for Troubled Times': 5.0,
#   'An Enchanted Season (Psy-Changeling #0.5; Murphy Sisters #1)': 4.0,
#   'Art History, Volume I (w/CD-ROM)': 4.0,
#   'Crisis on Infinite Earths': 3.0,
#   'Conjure Wife and Our Lady of Darkness (Tor Double)': 4.0,
#   'The Strange Case of Dr. Jekyll and Mr. Hyde and Other Stories ': 4.0,
#   'The Strange Case of Dr. Jekyll and Mr. Hyde and Other Stories (Barnes & Noble Classics)': 4.0,
#   'The Strange Case of Dr. Jekyll and Mr. Hyde and Other Stories (Barnes  Noble Classics Series)': 4.0,
#   'The Strange Case of Dr. Jekyll and Mr. Hyde and Other Stories': 4.0,
#   'By Arrangement': 4.0,
#   'Wicked Lies': 5.0,
#   'Selected Works of Robert Louis Stevenson': 4.0,
#   'Lie by Moonlight (Vanza, #4)': 4.0,
#   'The Cry of the Icemark (The Icemark Chronicles, #1)': 5.0,
#   'The Cry Of The Icemark (The Icemark Chronicles, #1)': 5.0,
#   'The Awakening (Montgomery/Taggert, #12)': 5.0,
#   'Magnificent Folly (Sedikhan, #16)': 4.0,
#   "Grimm's Fairy Tales, Volume 2: The Wolf and the Seven Little Kids, the Pack of Ragamuffins, Brother and Sister, the Three Snake-Leaves, the Boots of Buffalo-Leather, the Drummer, and Others": 4.0,
#   'Promises for You: From the New International Version': 5.0,
#   'Art History: Vol. 1': 4.0,
#   'Small Animal Surgery E-Dition: Text with Continually Updated Online Reference [With Online Reference Access]': 5.0,
#   'The Strange Case of Dr Jekyll and Mr Hyde and  Other Stories': 4.0,
#   'The Strange Case of Dr Jekyll and Mr Hyde and Other Stories': 4.0,
#   'The Strange Case Of Dr. Jekyll And Mr. Hyde And Other Stories': 4.0,
#   "The Year's Best Fantasy and Horror: Tenth Annual Collection": 3.0,
#   'Jackpot': 4.0,
#   'Honeyed Seduction': 4.0,
#   'The Enchantment ': 5.0,
#   'Urban Shaman  (Walker Papers, #1)': 5.0,
#   'Secretos De Un Matrimonio': 5.0,
#   'Lucky You.': 4.0,
#   'My Forever Love': 4.0,
#   "Dr. Jekyll and Mr. Hyde and Other Stories (Everyman's Library)": 4.0,
#   'My Surrender (The Rose Hunters Trilogy #3)': 4.0,
#   'The Siren Song (Cronus Chronicles, #2)': 4.0,
#   'Indigo': 5.0},
#  ' Debra (WifeEclectic)': {'Baby Chronicles: My Very Own Story: from pre-natal to pre-school': 5.0},
#  ' Doris Powell': {'Psalms for Zero Gravity': 5.0},
#  ' Dr. Michael Galvin': {"God Isn't Here: A Young American's Entry into World War II and His Participation in the Battle for Iwo Jima": 5.0},
#  ' Fernando Brito': {"Front Row Center 2: Inside the World's Greatest Air Shows": 4.0},
#  ' Jan  Vajda': {"John Grisham: A Reader's Checklist and Reference Guide": 5.0,
#   'John Grisham: Best-Selling Author': 5.0,
#   'Czech and Slovak Federal Republic (Occasional Papers)': 5.0,
#   'Literary Companion Contemporary Auths: John Grisham - L': 5.0,
#   'Grace Notes': 5.0},
#  ' Jordan': {'The Day It Rained Hearts': 5.0,
#   'Four Valentines in a Rainstorm': 5.0},
#  ' Julie': {'Sacra Pagina: The Gospel of Luke': 5.0},
#  ' Lady Jayne *~*The Beach Bandida*~*': {'Room Service (Do Not Disturb #6)': 4.0},
#  ' Linda (Miss Greedybooks)': {'Detroit Is My Own Home Town': 5.0,
#   'Herbalism: Using Herbs for Stress Relief and Common Ailments (New Life Library)': 5.0,
#   'Playing Soldiers in the Dark': 4.0},
#  ' Marla': {'Sheriff Luke Ludd': 3.0},
#  ' Martin': {"Pandora's Box: Pandora's Box": 4.0,
#   'Spawn of Hell': 5.0,
#   'Idole.': 5.0,
#   'The Movie': 5.0},
#  ' Ms. Crystal': {'The Great Rescue': 3.0},
#  ' Mummy Cat Claire': {'The Runaway Pumpkin': 3.0},
#  ' Qurban ': {'Questions of Character: Illuminating the Heart of Leadership Through Literature': 4.0,
#   'The Races of Afghanistan': 4.0},
#  ' Sara ': {'Microcosmos: The Invisible World of Insects': 3.0,
#   'Stokes Guide to Animal Tracking and Behavior': 5.0,
#   'The Book of Field & Roadside: Open-Country Weeds, Trees, and Wildflowers of Eastern North America': 5.0},
#  ' Souad ': {'Mon Egypte: Dialogues Avec Mohamed Salmawy': 4.0},
#  ' The Black Geek': {'The Darker Face of the Earth': 4.0,
#   'The Green Belt Movement: Sharing the Approach and the Experience': 4.0},
#  ' amapola': {'The Man with a Shattered World: The History of a Brain Wound': 5.0,
#   'Battle of Wits: The Complete Story of Codebreaking in World War II': 5.0},
#  ' imad  Ali': {"Oxford Advanced Learner's Dictionary of Current English [With CDROM]": 4.0},
#  ' john': {'Life Force: The Psycho-Historical Recovery of the Self': 5.0,
#   'Life Force: The Psycho-Historical Recovery of the Self ': 5.0,
#   "Jazz: New Perspectives On The History Of Jazz By Twelve Of The World's Foremost Jazz Critics And Scholars": 4.0,
#   'Preserving Cultural Landscapes in America': 3.0},
#  ' ~*~Princess Nhya~*~': {'Against the Wind': 1.0,
#   'Chocolate Covered Forbidden Fruit': 3.0},
#  ' ~Geektastic~': {'Cart and Cwidder (The Dalemark Quartet, #1)': 5.0,
#   'What We Do Now': 4.0},
#  '!ginger!': {'Pact': 4.0},
#  '"KayFey"': {'Maison Ikkoku: Welcome Home (Maison Ikkoku, #14)': 5.0},
#  '"The Jo"': {'Fer De Lance': 5.0},
#  '#daddy D': {"Where's Waldo: The Complete Set": 5.0},
#  '$hanel': {"A Smart Girl's Guide to Starting Middle School: Everything You Need to Know About Juggling More Homework, More Teachers, and More Friends": 5.0},
#  '&#x1f4ae;Geraldine&#x1f4ae;': {'Time: Hurricane Katrina: The Storm That Changed America': 3.0},
#  "'Aussie Rick'": {'The Gardeners of Salonika': 4.0,
#   'Gardeners of Salonika': 4.0,
#   'Like Men of War: Black Troops in the Civil War': 4.0,
#   'The Fall of Carthage': 5.0,
#   'The Punic Wars': 5.0,
#   'Utmost Savagery: The Three Days of Tarawa': 5.0,
#   'Soldiers of the Sun: The Rise and Fall of the Imperial Japanese Army': 4.0,
#   'The Peninsular War: A New History': 4.0,
#   'The Enemy at Trafalgar: Eyewitness Narratives,Dispatches and Letters from the French and Spanish Fleets': 3.0,
#   "Caesar's Legion: The Epic Saga of Julius Caesar's Elite Tenth Legion and the Armies of Rome": 4.0,
#   'The Commander, a Life of Barclay de Tolly': 4.0,
#   'The Last Battle: The Mayaguez Incident and the End of the Vietnam War': 5.0,
#   'The Grim Reaper: Machine Guns And Machine-gunners In Action': 3.0,
#   'Hannibal': 3.0,
#   "The Road to Rivoli: Napoleon's First Campaign": 4.0,
#   'The Great Game: The Struggle for Empire in Central Asia': 5.0,
#   'The Quest for the Lost Roman Legions: Discovering the Varus Battlefield': 5.0,
#   'Voices of Silence: The Alternative Book of First World War Poetry': 3.0,
#   'The Great Game': 5.0,
#   "The Battle of New Orleans: Andrew Jackson and America's First Military Victory": 3.0,
#   'Inferno: The Fiery Destruction of Hamburg, 1943': 4.0,
#   "Death's Men: Soldiers of the Great War": 5.0,
#   'A History of the French Navy, From Its Beginnings to the Present Day': 3.0,
#   'Chopin in Paris: The Life and Times of the Romantic Composer': 5.0,
#   "Rommel's Greatest Victory": 4.0,
#   'History of the Wars, Vol I: Books 1-2 (Persian War)': 4.0,
#   'Before Antietam: The Battle for South Mountain': 4.0,
#   'Journal of the Waterloo Campaign Kept Throughout the Campaign of 1815': 3.0,
#   'Wilderness Empire (Wilderness Empire, 1755)': 5.0,
#   'Wilderness Empire (Winning of America)': 5.0,
#   'Wilderness Empire (Narratives Of America, Book Ii)': 5.0},
#  "'Izzat Radzi": {'Extraordinary Popular Delusions and The Madness of Crowds, Volume 1': 4.0,
#   "Major Themes of the Qur'an": 4.0,
#   'Memoirs of Extraordinary Popular Delusions & the Madness of Crowds 2': 4.0},
#  "'becca": {'Creative Victory: Reflections on the Process of Power from the Collected Works of Carlos Castaneda': 4.0,
#   'Forbidden Images: The Secrets of the Tarot': 3.0},
#  "'carl Vega": {'A Dictionary of English and Portuguese Equivalent Proverbs': 5.0,
#   "Rick Steves' Spanish & Portuguese Phrasebook & Dictionary  ": 5.0},
#  "'hayat": {'Ezra Pound And Dorothy Shakespear: Their Letters:  1910 1914': 3.0},
#  "'kris Pung": {'The Books of Magic, Volume 2: Summonings': 4.0,
#   'Wolverine: Enemy of the State, Volume 1': 4.0},
#  "'neeylza'": {'Becoming a Witch': 4.0},
#  "'stina": {'"Why Do I Love These People?": Understanding, Surviving, and Creating Your Own Family': 5.0},
#  "'trie": {"D'Aulaires' Book of Greek Myths": 5.0,
#   "D'aulaires' Book of Greek Myths": 5.0},
#  '(0v0)': {'Boomeritis: A Novel That Will Set You Free!': 3.0},
#  '(Jen) The Artist Librarian': {'Usagi Yojimbo, Vol. 17: Duel at Kitanoji (Usagi Yojimbo, #17)': 5.0},
#  '(Kelly)~Got Fiction?~ Oakes': {'The Jury (Sisterhood, #4)': 1.0},
#  '(NS) Becca': {'Snow Bored': 5.0},
#  '(NS) Brea M': {'The Flying Bed': 3.0},
#  '(NS) Dana': {'Bill Gates': 4.0,
#   "Fair Ball!: 14 Great Stars from Baseball's Negro Leagues": 5.0},
#  '(NS) Heatherk': {'When Jessie Came Across the Sea': 4.0},
#  '(NS) Laura Jackson': {'The Gospel Cinderella': 4.0},
#  '(NS) Lisa': {'Buzz': 3.0},
#  '(NS) Panagiota Angelos': {'Cinderlily: A Floral Fairytale': 4.0},
#  '(a)lyss(a)': {'Eyewitness To Power: The Essence of Leadership Nixon to Clinton': 4.0,
#   'Talking About a Revolution: Interviews with Michael Albert, Noam Chomsky, Barbara Ehrenreich, bell hooks, Peter Kwong, Winona LaDuke, Manning Marable, Urvashi Vaid, and Howard Zinn': 4.0,
#   'Brown Face Big Master': 5.0,
#   'Public-Private Policy Partnerships': 4.0},
#  '***Dave Hill': {'Gods and Androids': 3.0,
#   'The Spenser Collection: Volume I (Spenser, #27-28)': 3.0,
#   'Darkness of the Light': 4.0,
#   'Fall of Knight (Modern Arthur, #3)': 3.0,
#   'The Tale of Jack Frost': 4.0},
#  '**Forever**': {'Julie of the Wolves Study Guide': 4.0},
#  '**ladybug**': {'Resolving Grievances in the Nursing Home: A Study of the Ombudsman Program': 5.0},
#  '*Avonna': {'Agatha Christie': 4.0,
#   'China Trade (Lydia Chin & Bill Smith, #1)': 4.0},
#  '*Kashi*': {'Cuentos Eroticos de Navidad': 3.0},
#  '*Kate': {'Teaching Shakespeare. (Lernmaterialien)': 5.0},
#  '*TANYA*': {'The Bone Collector (Lincoln Rhyme, #1)': 5.0,
#   'El Coleccionista De Huesos (Lincoln Rhyme, #1)': 5.0,
#   'Apt Pupil': 3.0,
#   'The Silence of the Lambs/Red Dragon': 5.0,
#   'Red Dragon/The Silence of the Lambs': 5.0,
#   'Red Dragon and Silence of the Lambs': 5.0,
#   'The Vanished Man (Lincoln Rhyme, #5)': 4.0,
#   'The Empty Chair (Lincoln Rhyme, #3)': 5.0,
#   'The Twelfth Card (Lincoln Rhyme, #6)': 3.0,
#   'The Stone Monkey (Lincoln Rhyme, #4)': 4.0,
#   "Temptation's Kiss ": 3.0,
#   'Demon Rumm ': 3.0,
#   "Thursday's Child": 3.0,
#   'In a Class By Itself': 3.0,
#   'The Silken Web': 3.0,
#   "Tomorrow's Promise": 3.0,
#   'Demon Rumm': 3.0,
#   "Temptation's Kiss": 3.0,
#   "The Devil's Own (Hellraiser #2)": 4.0,
#   'Eloquent Silence': 3.0,
#   'Temperatures Rising': 4.0,
#   'A Secret Splendor ': 4.0,
#   'Sandra Brown: Three Complete Novels (Best Kept Secrets, Mirror Image, and Slow Heat in Heaven)': 5.0,
#   'A Secret Splendor': 4.0,
#   'Mirror Image / Best Kept Secrets / Slow Heat In Heaven (Abridged)': 5.0,
#   'The Hannibal Lecter Trilogy': 5.0,
#   'Island of Saints: A Story of the One Principle That Frees the Human Spirit': 4.0,
#   'White Lies (Rescues, #4)': 4.0,
#   'The Vanished Man': 4.0,
#   'El Hombre Evanescente (Lincoln Rhyme, #5)': 4.0,
#   'Seducing Simon': 3.0,
#   'Hannibal Lecter Omnibus Sso': 5.0,
#   'Notorious': 3.0,
#   'The Stone Monkey': 4.0,
#   'El Mono De Piedra (Lincoln Rhyme, #4)': 4.0,
#   'The Coffin Dancer / The Empty Chair / The Stone Monkey (Lincoln Rhyme, #2-4)': 5.0,
#   'The Stone Monkey (Lincoln Rhyme #4)': 4.0},
#  '*danielle*': {'Mirror Dreams': 4.0},
#  '*elasticfate': {'The Secret of the Shadow: The Power of Owning Your Story': 3.0},
#  '*erin*': {'Critical Care Nursing Made Incredibly Easy!': 4.0},
#  '*skittles*': {'Phillis Wheatley: Slave and Poet': 3.0},
#  '-': {'William James Durant: An Intellectual Biography': 4.0},
#  "-;'MrSz.MyRiAh';-": {'The First Part Last (Heaven, #2)': 5.0},
#  '-Marisa -': {"Brain Writing!: See Inside Your Own Mind and Others' with Handwriting Analysis": 5.0},
#  '-ed- Erwin': {'History of US Naval Operations in WWII, 15 Vols': 5.0,
#   'Seven Summits Solo': 3.0},
#  '-uht!': {'Language and Problems of Knowledge (Current Studies in Linguistics)': 3.0},
#  '.': {'In a Dark, Dark Wood (The Story box)': 5.0,
#   'Across the Frontiers': 4.0},
#  '..': {'Cremaster 5': 4.0},
#  '...bethany...': {'Zen Flowers: Chabana for the Tea Ceremony': 4.0},
#  '...m...': {'Jungle Animals': 4.0},
#  '.: .A.E.R.': {'A Psychological Approach to Fiction: Studies in Thackeray, Stendhal, George Eliot, Dostoevsky, and Conrad': 4.0,
#   'The Gig Bag Book Of Picture Chords': 5.0},
#  '.HaiMe.': {'Noli me tangere - Ne me touche pas': 5.0},
#  '.lAuReN:)': {'Dolley Madison': 4.0},
#  '0': {'The Seminar of Jacques Lacan: The Four Fundamental Concepts of Psychoanalysis (Seminar of Jacques Lacan)': 1.0,
#   'The Prose of the World': 4.0,
#   'The Four Fundamental Concepts of Psycho-Analysis': 1.0,
#   'Husserl at the Limits of Phenomenology': 3.0},
#  '01Kaylah': {'The Mercy Seat': 4.0},
#  '01dallinc': {'Gadiantons and the Silver Sword (Tennis Shoes, #2)': 4.0,
#   'Gadiantons and the Silver Sword (The "Tennis Shoes" Gang Series)': 4.0},
#  '02michellek': {'Little House by Boston Bay (Little House: The Charlotte Years, #1)': 4.0},
#  '03MckenzieO': {'The Turning Point': 5.0},
#  '04allies': {'Wonder of the World': 4.0},
#  '04brandonr': {"Edward Albee's Who's Afraid of Virginia Woolf and Other Works (Monarch Notes)": 4.0},
#  '07nickc': {"Beyond Basketball: Coach K's Keywords for Success": 3.0},
#  '0spinboson': {"Pandora's Hope: Essays on the Reality of Science Studies": 5.0},
#  '1 Samuel S': {'Exploring Mars (The Lucent Library of Science and Technology)': 5.0},
#  '1.1': {'Bang!: Getting Your Message Heard in a Noisy World': 3.0,
#   'The Rover': 4.0,
#   'How Happy to Be': 3.0,
#   'The Arms Bazaar': 3.0,
#   "Orwell's Message: 1984  the Present": 4.0,
#   'Crackpot': 4.0},
#  '10-11 Bryanna': {"Teacher's Pet (Wild at Heart, #7)": 5.0},
#  '10-11 Jonathan': {'September 11: Attack on America': 4.0},
#  '1000 +': {'By Any Other Name': 4.0},
#  '1000 Cutts': {'Cliff Notes on: All the Pretty Horses': 1.0},
#  '10thumbs': {'Double Duce': 4.0},
#  '10~11 Madison Markwood': {'Escape from Slavery: The Boyhood of Frederick Douglass in His Own Words': 4.0},
#  '11811 (Eleven)': {"Ice Blink: The Tragic Fate of Sir John Franklin's Lost Polar Expedition": 3.0,
#   "Assortment Louis L'amour": 3.0,
#   "Louis L'Amour Collection": 3.0},
#  '123chase': {'Mickey Mantle': 4.0},
#  '12barbluez': {'Lou Reed: Walk on the Wild Side: The Stories Behind the Songs': 3.0},
#  '16adauber': {'Lifestories: Finding God\'s "Voice of Truth" Through Everyday Life': 5.0},
#  '17th Century Eco J': {'Monochords': 3.0},
#  '18Enrique Moya': {'Thank You, Dr. Martin Luther King, Jr!': 3.0,
#   'Thank You, Dr. Martin Luther King, Jr.!': 3.0},
#  '18rosebuds': {"The Mom's Guide to Earning and Saving Thousands on the Internet": 3.0},
#  '1C7': {"On Measure for Measure: An Essay in Cristicsm of Sheakespeare's Drama": 3.0},
#  '1amanda1amanda1': {'Lewis Carroll Among His Books: A Descriptive Catalogue of the Private Library of Charles L. Dodgson': 3.0},
#  '1luvbooks': {'The Hostage Bride': 1.0},
#  '1moongoddess': {'How to Set His Thighs on Fire: 86 Red-Hot Lessons on Love, Life, Men, and (Especially) Sex': 4.0},
#  '1oel': {'Charity. Die Herren der schwarzen Festung. Drei Charity Romane in einem Band (Charity, #7-9)': 5.0},
#  '20hrsinamerica': {'Organizations in Depth: The Psychoanalysis of Organizations': 3.0},
#  '20vbredsten': {'Steve Jobs': 5.0, 'Steve Jobs: Thinks Different': 5.0},
#  '22016Patrice L.': {'Rumpelstilskin': 5.0},
#  '2222': {'Borrowed Words: Translation, Imitation, and the Making of the Nineteenth Century Novel in Spain': 3.0},
#  '223rem': {'The Secret of the Garden: Criminal? Surgeon? Jockey? Friend?': 5.0},
#  '27282': {'Love and Hate in the Analytic Setting': 5.0},
#  '2Karl Tessier-Ashpool': {'The Caverns of Kalte (Lone Wolf, #3)': 4.0},
#  '3Ralph Lemar': {'Batman Beyond: No Place Like Home': 5.0},
#  '3Shaniamos*09': {"Jayd's Legacy (Drama High, #3)": 5.0},
#  '3a Student': {"Ben Franklin's Fame (Blast to the Past #6)": 4.0},
#  '3l3azar': {'Habitat Bio Climatique': 4.0},
#  '3rd Grade Centennial 2013/2014': {"Pirates Don't Wear Pink Sunglasses (The Adventures of the Bailey School Kids, #9)": 4.0},
#  '3rishib': {'War Dog': 5.0},
#  '4.ashante!': {'I, Tina': 5.0},
#  '41m33': {'Fundamentals of Real Analysis': 5.0},
#  '47Time': {'Artesia Volume 3: Afire - The Third Book Of Dooms': 5.0,
#   'Dicks, Volume 1': 5.0},
#  '4D': {"Graphic Design for the 21st Century: 100 of the World's Best Graphic Designers": 3.0},
#  '4Georgia': {'The Gun (Bluford High, #6)': 5.0},
#  '4cats': {'Echec De Maigret': 5.0,
#   'Glorafilia: The Venice Collection: 25 Original Projects in Needlepoint and Embroidery': 4.0,
#   'Glorafilia: Venice Collection   25 Original Projects In Needlepoint And Embroidery': 4.0,
#   'The Blind Side (Ernest Lamb #1)': 3.0},
#  '4danielle': {'Behold the Lamb of God: A Treasury of Catholic Truths, Teachings and Traditions': 5.0},
#  '4th-8th': {"In the Mind's Eye: Visual Thinkers, Gifted People with Dyslexia and Other Learning Difficulties, Computer Images and the Ironies of Creativity": 5.0,
#   "In the Mind's Eye: Visual Thinkers, Gifted People with Learning Difficulties, Computer Images, and the Ironies of Creat": 5.0},
#  '4triplezed': {'A Writer at War: A Soviet Journalist with the Red Army, 1941-1945': 4.0,
#   'A Writer at War: Vasily Grossman with the Red Army 1941-1945': 4.0,
#   'Despatches From The Barricades: An Eye Witness Account Of The Revolutions That Shook The World, 1989 90': 4.0,
#   'Cavaliers and Roundheads': 4.0,
#   'Cavaliers and Roundheads: The English Civil War, 1642-1649': 4.0,
#   'The Undefeated: The Rise, Fall And Rise Of Greater Japan': 4.0,
#   'The Undefeated: The Rise, Fall and Rise of Greater Japan': 4.0,
#   'A Writer at War: Vasily Grossman with the Red Army': 4.0,
#   'Going to the Wars: The Experience of the British Civil Wars, 1638-1651': 5.0},
#  '5': {'Fear and Loathing: The Strange and Terrible Saga of Hunter S. Thompson': 3.0,
#   'Cosmic Trigger 3: My Life After Death': 5.0},
#  '528_Mary F.': {'Elie Wiesel: Surviving the Holocaust, Speaking Out Against Genocide': 5.0},
#  '528_Tracy': {'Grandma Hekmatt Remembers: An Arab-American Family Story': 4.0,
#   'Me, Hailey!': 3.0},
#  '529_Gary': {'Counting Coup: Becoming a Crow Chief on the Reservation and Beyond': 5.0,
#   'Oranges on Golden Mountain': 4.0},
#  '538am_erin': {'La Mariposa': 5.0},
#  '543wd': {'Autumn Sonata: Selected Poems': 5.0},
#  '5andrina': {'La aldea perdida': 3.0},
#  '5dd': {'Applied Optimal Control: Optimization, Estimation and Control': 4.0},
#  '5greenway': {'The Human Being: Jesus and the Enigma of the Son of the Man': 4.0,
#   'Brothers Under the Skin: Travels in Tyranny': 5.0},
#  '63alfred': {'Momentum, Heat, And Mass Transfer': 4.0},
#  '6655321': {'Magika Hiera: Ancient Greek Magic and Religion': 4.0,
#   'Peasants, Rebels, and Outcastes: The Underside of Modern Japan': 3.0,
#   'Strategy of Deception': 3.0,
#   'Queer Studies: A Lesbian, Gay, Bisexual, and Transgender Anthology': 4.0,
#   'Feminism and Foucault: Violence, Poverty, and Prostitution': 3.0},
#  '6th Grade Honors Language Arts Class': {"Wonder's First Race (Thoroughbred, #3)": 4.0},
#  '7$MartyQ': {'Steel Shark (Sea Wolf #1)': 5.0},
#  '704alexandria': {'Getting Burned (Nancy Drew: Girl Detective, #20)': 4.0},
#  '7709julia': {'Ella The Elegant Elephant Read Along Library': 5.0},
#  '78sunny': {'Der Untergang (Die Chronik der Unsterblichen, #4)': 5.0,
#   'Silvestertuntenball und andere Schwulcomix': 5.0},
#  '7BettyV': {'Two Badges: The Lives of Mona Ruiz': 5.0},
#  '7amina': {'Goosebumps Monster Blood Pack (Goosebumps, #2, #3, #5)': 4.0},
#  '7jane': {'Hungry Planet': 4.0,
#   "Haruki Murakami's The Wind-up Bird Chronicle: A Reader's Guide": 4.0,
#   'As I Crossed a Bridge of Dreams: Recollections of a Woman in Eleventh-Century Japan': 4.0,
#   'Reaching for the Invisible God: What Can We Expect to Find?': 4.0,
#   'Emma, Vol. 01': 4.0,
#   'Thrump-O-Moto': 4.0,
#   'Relatos de un Peregrino Ruso: A su Padre Espiritual': 4.0,
#   'de Los Nombres de Cristo': 4.0,
#   'Boring Postcards USA': 4.0,
#   'Jesus of Nazareth: From the Baptism in the Jordan to the Transfiguration': 4.0,
#   'The Star Diaries': 4.0,
#   'POPism: The Warhol Sixties': 4.0,
#   'A Foxfire Christmas: Appalachian Memories and Traditions': 4.0,
#   'Luis de Leon: The Names of Christ': 4.0,
#   'Ragged Dick, Or, Street Life in New York with the Boot-Blacks': 4.0,
#   'As I Crossed a Bridge of Dreams: Recollections of a Woman in Eleventh Century Japan': 4.0,
#   'de los Nombres de Cristo': 4.0,
#   'The Collected Letters of St. Teresa of Avila': 4.0,
#   'Gabriel of Our Lady of Sorrows: Life and Prayers': 4.0,
#   'The Way of a Pilgrim: Annotated & Explained': 4.0,
#   'The Way Of A Pilgrim': 4.0,
#   'The Way of a Pilgrim': 4.0,
#   'Breakfast, Lunch, Tea: The Many Little Meals of Rose Bakery': 4.0,
#   'The Cranks Bible': 4.0,
#   'The Rosary for the Holy Souls in Purgatory': 4.0,
#   'Material World: A Global Family Portrait': 4.0,
#   'Thrump O Moto: A Fantasy': 4.0},
#  '7l2': {'From Geek to Goddess (Zodiac Girls, #1)': 4.0},
#  '7niko': {'Skateboard Renegade: Is image everything? (Matt Christopher Sports Bio Bookshelf (Paperback))': 5.0},
#  '84-The_enlightment_of_Doctor_Grace_part5_Jesus': {"The Vanishings: Four Kids Face Earth's Last Days Together  (Left Behind: The Kids, #1)": 5.0},
#  '905_schrama': {'The Earrings': 3.0},
#  'A': {'Burden of Proof 2e: An Introduction to Argumentation and Guide to Parliamentary Debate': 4.0,
#   'Burden of Proof: An Introduction to Argumentation and Guide to Parliamentary Debate': 4.0,
#   'How Invention Begins: Echoes of Old Voices in the Rise of New Machines': 5.0,
#   'Dr. Zhivago: Curriculum Unit': 1.0,
#   'The Demon Ororon, Vol. 4 (The Demon Ororon, #4)': 3.0,
#   'Fat Cats and Running Dogs: The Enron Stage of Capitalism': 5.0,
#   'In a While Crocodile (Stanley, #3)': 3.0,
#   'Jay DeFeo and The Rose': 5.0,
#   'Surrealist Painters and Poets: An Anthology': 3.0,
#   'Mujeres asesinas 2': 3.0,
#   'America in Passing': 5.0,
#   "Lover's I Ching": 3.0,
#   'Bull Of The Woods: The Gordon Gibson Story': 5.0,
#   'Myron': 3.0,
#   'Hit And Run (Point Horror, #26)': 3.0,
#   'Maxfield Parrish: The Early Years, 1893 1930. Commentary By Paul Skeeters.': 4.0,
#   'Beacon Best of 2001 (Beacon Anthology)': 5.0,
#   'Salome, the Duchess of Padua, Vera': 3.0,
#   "Vij's: Elegant and Inspired Indian Cuisine": 5.0,
#   'Robert Adams: California: Views by Robert Adams of the Los Angeles Basin, 1978-1983': 4.0,
#   "The Artist's Complete Guide to Drawing the Head": 4.0,
#   "The Pixies' Doolittle": 4.0,
#   'Nancy Drew: #11,37': 5.0,
#   'The Northwoods Table: Natural Cuisine Featuring Native Foods': 4.0,
#   'Clara Barton: Founder of the American Red Cross': 5.0,
#   "Studies in Honor of the Late Hasan M. Balyuzi (Studies in the Babi & Baha'i Religions, Volume 5)": 5.0,
#   'Readings in the Philosophy of Social Science': 4.0,
#   'Philosophies of Science': 4.0,
#   'Biting Off the Bracelet: A Study of Children in Hospitals': 4.0,
#   'Virginia Woolf and the Fictions of Psychoanalysis': 4.0,
#   'Death by Chocolate Cakes: An Astonishing Array of Chocolate Enchantments': 3.0,
#   'The Story of the Statue of Liberty': 4.0,
#   'Living Beyond Loss: Death in the Family': 5.0,
#   "Caesar's Conquest of Gaul (World History)": 3.0,
#   'The Comic Worlds of Peter Arno, William Steig, Charles Addams, and Saul Steinberg': 4.0,
#   'A Maisy Le Gusta Conducir': 3.0,
#   'Uncle Scrooge #361': 4.0,
#   'Sex and Murder.com (Paul Turner, #6)': 4.0,
#   'The Pleasure Principle: Sex, Backlash, and the Struggle for Gay Freedom': 3.0,
#   'Henry E. Huntington and the Creation of Southern California': 4.0,
#   "A Treasury of Christmas Miracles: True Stories of God's Presence Today": 5.0,
#   'In the Drink (Doubleday Graphic Novels)': 4.0,
#   'In the Drink': 4.0,
#   'Cafard, Vertiges Et Vodkas Glace': 4.0,
#   'Linear and Generalized Linear Mixed Models and Their Applications': 3.0,
#   'Open Wound: Chechnya 1994-2003': 5.0,
#   'Viva Vodka: Colorful Cocktails with a Kick': 4.0},
#  'A Anders': {'From Romanticism to Critical Theory: The Philosophy of German Literary Theory': 4.0,
#   'Kant on the Human Standpoint': 4.0},
#  'A B': {'Paula Deen  Friends: Paula Deen  Friends': 4.0,
#   'Streams of Silver: The Graphic Novel (Legend of Drizzt: The Graphic Novel, #5)': 4.0},
#  'A Bald Mage** Steve': {"Sharpe's Revenge (Sharpe, #19)": 3.0,
#   'Under the Eagle (Eagle, #1)': 4.0,
#   'The Complete Illustrated Guide to the Kings & Queens of Britain': 4.0,
#   'The Complete Illustrated Guide to the Kings & Queens of Britain: A Magnificent and Authoritative History of the Royalty of Britain - The Rulers, Their Consorts and Families, and the Pretenders to the Throne': 4.0,
#   'Doctor Who: The Abominable Snowmen (BBC TV Soundtrack)': 4.0,
#   'Doctor Who and the Horror of Fang Rock (Doctor Who Target Library)': 4.0,
#   'The Lost History of Aztec & Maya': 4.0,
#   'The Whitechapel Horrors': 3.0},
#  'A Blane': {'Dynamic Stretching and Kicking': 3.0},
#  'A Fikri': {'Oral & Intravenous Bisphosphonate-Induced Osteonecrosis of the Jaws: History, Etiology, Prevention, and Treatment': 5.0},
#  'A Girl Has No Name': {'Woyzeck/Leonce und Lena': 4.0,
#   'Woyzeck. Leonce und Lena': 4.0},
#  'A Holscher': {'Ancient Rome: Waldorf Education Resources': 5.0},
#  'A Ivy': {"Clarion's Call": 4.0},
#  'A J': {"Ernest Hemingway's the Sun Also Rises": 4.0},
#  'A Jaff': {'Survive the Savage Sea': 5.0},
#  'A K': {'On a Roll: Or How a Kid from the Bronx Started with Hot Dogs and WoundUp Making a Fortune': 5.0},
#  'A Man': {'Erich Fromm': 4.0},
#  'A Miller': {'The Four Grannies': 4.0},
#  'A Miuda Geek': {'Foxmask (Saga of the Light Isles, #2)': 3.0},
#  'A Randy Bozarth': {'Walking Jazz Lines for Bass': 3.0},
#  "A Reader's Heaven": {'The Watchmen': 3.0},
#  'A Scharf': {'Memories of a Giant: Eulogies in Memory of Rabbi Dr. Joseph B. Soloveitchik (Rabbi Soloveitchik Library, vol. 1)': 4.0,
#   'Reflections of the Rav: Lessons in Jewish Thought Adapted from the Lectures of Rabbi Joseph B. Soloveitchik, Vol. 1 ': 3.0,
#   'Lost Princess: And Other Kabbalistic Tales of Rebbe Nachman of Breslov': 3.0},
#  'A Smith': {'Human Geography In Action': 4.0},
#  'A Voracious Reader (a.k.a. Carol)': {'Spike and Dru: Pretty Maids All in a Row (Buffy the Vampire Slayer)': 4.0,
#   'Buffy cazavampiros: Spike & Dru: Bonitas doncellas, todas en fila': 4.0,
#   'Buffy The Vampire Slayer: The Monster Book': 4.0},
#  'A Young': {"The Girls of Summer: The U.S. Women's Soccer Team and How It Changed the World": 5.0},
#  "A'Llyn": {'No Mas Berrinches: Consejos Para Lograr la Armonia Entre Padres E Hijos': 4.0,
#   'Loom and Spindle, or Life Among the Early Mill Girls': 4.0},
#  "A'ndrea Wilson": {'Shattered Trust': 3.0, 'Icing on the Cake': 5.0},
#  'A-Leee': {'Rescue 007: The Untold Story of Kal 007 and Its Survivors': 5.0,
#   'Slave of Desire: Love, Sex, and Death in the 1001 Nights': 3.0,
#   '1001 Nights Exotica': 5.0,
#   '1001 Nights Of Seafood Delights': 4.0,
#   'Adobe PageMaker 7.0 Basics': 4.0,
#   'Divan-I Parvin Itisami: Qasaid, Masnaviyat, Tamsilat, Va Muqattaat': 5.0,
#   'Oracle 9i: SQL Exam Cram 2 (Exam Cram 1z0-007)': 1.0,
#   '1002 Nights Exotica': 5.0},
#  'A-gel Ramboyong': {'Bantam: Indonesia Regional Maps (Periplus Travel Maps)': 1.0},
#  'A-j Banks': {'Tom Hunter: Living in Hell and Other Stories': 4.0},
#  'A-man': {"Dora's Fairy-Tale Adventure (Dora the Explorer)": 5.0},
#  'A-ron': {'The Knowledge Web: From Electronic Agents to Stonehenge and Back -- And Other Journeys Through Knowledge': 3.0,
#   'The Arab World': 5.0,
#   "California's Changing Landscapes: Diversity and Conservation of California Vegetation": 5.0,
#   'Hollow City: The Siege of San Francisco and the Crisis of American Urbanism': 1.0,
#   'Latin Moon in Manhattan: A Novel': 3.0,
#   'Luna latina en Manhattan': 3.0},
#  'A.': {"Ariadne's Web (Book of the Gods, #2)": 1.0,
#   'Borrowed Time': 4.0,
#   'Resurrection Day': 5.0,
#   'Practical Business Math Procedures W/ DVD, Business Math Handbook, and Wall Street Journal Insert': 3.0,
#   'The Hidden Roots of Aikido: Aiki Jujutsu Daitoryu - Secret Techniques of an Ancient Martial Art': 3.0,
#   'Legalines on Real Property Keyed to Dukeminier: Property : Adaptable to Fifth Edition of Dukeminier Casebook': 4.0,
#   'Heroes and Villains ': 5.0,
#   'Body Language': 3.0,
#   'Ship Schematics Punch Out Book (Star Wars, Episode II: Attack of the Clones)': 5.0,
#   'Memory: From Mind to Molecules': 5.0,
#   'On the Street Where I Lived': 1.0,
#   'Forged By Fire (Dragon Temple Saga, #3)': 3.0,
#   'Adorno: Disenchantment and Ethics': 5.0,
#   "Empire's children: The People of Tzintzuntzan": 3.0,
#   'Cuentos de mujeres solas': 4.0,
#   'Entwined Lives: Twins and What They Tell Us About Human Behavior': 4.0,
#   'Van Gogh': 3.0,
#   "The Sinner's Guide to the Evangelical Right": 4.0,
#   "My Son... My Hero: The True Story of Michael James' Brave Fight Against Childhood Leukemia": 5.0,
#   'Stuckness in the Fiction of Mervyn Peake': 4.0,
#   'Stolen Kisses (Love Stories For Young Adults, #37)': 4.0,
#   'Desire Lines: New and Selected Poems': 4.0,
#   'Making Waves Stories Of Participatory Communication For Social Change: A Report To The Rockefeller Foundation': 4.0,
#   'Anatomy for the Artist': 3.0,
#   'New and Selected Poems': 4.0,
#   'The Black Experience in Middle-Class America: Social Hierarchy and Behavioral Biology': 1.0,
#   'How to Draw People': 4.0,
#   "I Can't Find My Roller Skates": 1.0},
#  'A. Bowdoin Van Riper': {'Oops: 20 Life Lessons from the Fiascoes That Shaped America': 4.0},
#  'A. Breeze Harper': {'Granny Midwives and Black Women Writers: Double-Dutched Readings': 5.0,
#   'Beyond Fear: Twelve Spiritual Keys to Racial Healing': 5.0},
#  'A. Catherine Noon': {'Borders for Calligraphy: How to Design a Decorated Page': 5.0},
#  'A. Cox': {'Young People and Social Change': 3.0,
#   'Young People and Social Change: New Perspectives': 3.0,
#   'Reflexive Modernization: Politics, Tradition and Aesthetics in the Modern Social Order': 4.0},
#  'A. D. Jameson': {'American Made: New Fiction from the Fiction Collective': 4.0,
#   'Heretical Songs': 3.0},
#  'A. Daqn': {"Colette Rossant's After-Five Gourmet": 4.0},
#  'A. Dawes': {'The Cay (The Cay, #1)': 5.0,
#   'Reave the Just and Other Tales': 5.0,
#   'The Cay and Related Readings': 5.0,
#   'El Cayo (The Cay)': 5.0,
#   'El Cayo = The Cay': 5.0,
#   'The Cay': 5.0,
#   'The Amphora Project': 1.0,
#   'The Island of Dr. Death and Other Stories and Other Stories': 5.0,
#   'Calvin and Hobbes 1: Thereby Hangs a Tale': 5.0},
#  'A. Estevez': {"From My Grandmother's Kitchen: A Sephardic Cookbook- An exotic blend of Turkish, Greek, Bulgarian, Romanian & Spanish Cuisines": 5.0},
#  'A. Gulden': {"Oprah Winfrey Speaks: Insights from the World's Most Influential Voice": 3.0},
#  'A. J. McMahon': {'Philosophy: 100 Essential Thinkers': 1.0},
#  'A. Johnstone': {"Oppenheim's International Law, Volume 1: Peace": 1.0},
#  'A. L.': {'Egyptian Hieroglyphics and Their Meanings, 2nd Edition': 1.0,
#   'Spanish Verbs and Essentials of Grammar: A Practical Guide to the Mastery of Spanish': 4.0},
#  'A. Mary': {'Agnes Browne Trilogy Boxed Set: The Mammy, The Chisellers, The Granny (Agnes Browne, #1-3)': 3.0,
#   'Walking the Dog: And Other Stories': 4.0},
#  'A. P. D. G.': {'Risk, Ambiguity and Decision (Studies in Philosophy (New York, N.Y.).)': 4.0},
#  'A. S.': {'When China Ruled the Seas: The Treasure Fleet of the Dragon Throne, 1405-1433': 3.0},
#  'A. Saffaf': {'Le Commentaire De Texte En Histoire': 5.0},
#  'A. T. Adlen': {'Riddles of Identity in Modern Times (A History of Private Life, #5)': 3.0},
#  'A. Zavarelli': {'Exit Strategy: A Practical Guide to Selling Your Business': 5.0},
#  'A.-C.': {'These Modern Women: Autobiographical Essays from the Twenties': 4.0},
#  'A.A Sh.': {'Treasures from Above: Inspirational Gems; Poems of Praise': 4.0},
#  'A.B.': {'Troubling the Waters: Black-Jewish Relations in the American Century': 3.0},
#  'A.B. Gayle': {'I Once Had a Master': 5.0},
#  'A.C.': {'Death in the Funhouse: John Barth and Poststructuralist Aesthetics': 3.0,
#   'Enemy Combatant: My Imprisonment at Guantanamo, Bagram, And Kandahar': 5.0,
#   'A Party for the Girls: Six Stories': 5.0},
#  'A.C. Bauch': {'From the First Bite: A Complete Guide to Recovery from Food Addiction': 3.0,
#   'Finding Your Focus': 4.0,
#   'Bible Baby Names: Spiritual Choices from Judeo-Christian Sources': 4.0,
#   'Wee Willie Winkie': 4.0},
#  'A.D. Mercer': {'The Watertower': 5.0},
#  'A.D. Morel': {"Euell Gibbons' Beachcomber's Handbook": 5.0},
#  'A.D. Puchalski': {'Sewing Sculpture': 5.0},
#  'A.E. Curzon': {'No Boys Allowed': 5.0},
#  'A.E. Fuhrman': {'The Case of the Measled Cowboy (Hank the Cowdog, #33)': 4.0,
#   'The Case of the Double Bumblebee Sting': 4.0},
#  'A.E. Reiff': {"Little Boy: The Arts of Japan's Exploding Subculture": 4.0,
#   'The Artilect War: Cosmists Vs. Terrans: A Bitter Controversy Concerning Whether Humanity Should Build Godlike Massively Intelligent Machines': 3.0,
#   'Inventions': 3.0,
#   'Inventions: The Patented Works of R. Buckminster Fuller': 3.0},
#  'A.E. Shaw': {'The Tolkien Treasury': 5.0,
#   'A Tolkien Treasury': 5.0,
#   'The Tulip Touch': 5.0},
#  'A.G. Khaliq': {'Unglaubliche Ferien: Das Grosse Roald Dahl Lesebuch (das Wundermittel, die Zwicks stehen kopf, die Griaffe, der Peli und ich)': 5.0,
#   'Terrible Tricks [With Fake Maggots, Fake Flies, Fake Eyeballs, Etc.]': 5.0,
#   'Weird Tales, Fall 1990': 5.0,
#   'The Stratford Shakespeare Anthology (The Shakespeare Collection)': 5.0,
#   'A Second Roald Dahl Selection': 5.0,
#   'Roald Dahl Fiendish Faces [With Components]': 5.0,
#   'Roald Dahl Silly Scribbles [With Other]': 5.0,
#   'Ghastly Grub': 5.0,
#   'The Annotated Shakespeare Volume II: The Histories, Sonnets And Other Poems': 5.0,
#   'Roald Dahl Ghastly Grub [With Components]': 5.0},
#  'A.G. Lindsay': {'Fantastic Fabric Folding: Innovative Quilting Projects - Print on Demand Edition': 5.0},
#  'A.H.': {'Marilyn Monroe: The Biography': 4.0,
#   'Marilyn Monroe': 4.0,
#   'Marilyn Monroe - La Biografia': 4.0},
#  'A.H. Haar': {'Touching Peace': 5.0},
#  'A.H. Richards': {'The Nightmare Notebook': 3.0},
#  'A.J': {'Roman Warfare': 5.0,
#   'Roman Warfare (Smithsonian History of Warfare)': 5.0,
#   'Les guerres romaines, 281 av. J.-C.-476 ap. J.-C. ': 5.0},
#  'A.J.': {'The Old Arcadia': 1.0,
#   'Story: Substance, Structure, Style, and the Principles of Screenwriting': 3.0,
#   'Ninety-two in the Shade': 5.0,
#   'The Blood Countess': 1.0,
#   'Story': 3.0,
#   "Spurgeon's Sermon Notes: Over 250 Sermons Including Notes, Commentary and Illustrations": 3.0,
#   'Ninety-Two In The Shade': 5.0,
#   'The Book of the Courtier': 3.0},
#  'A.J. Aalto': {"I Have Lived in the Monster: Inside the Minds of the World's Most Notorious Serial Killers": 5.0},
#  'A.J. Aaron': {'A Journey Through The Tenth Dimension': 5.0,
#   'Traveling with Power: The Exploration and Development of Perception': 4.0},
#  'A.J. Boyd': {'Dictionary of the Ecumenical Movement': 5.0,
#   "The Church as Koinonia of Salvation: It's Structures and Ministries (Lutherans and Catholics in Dialogue, X) (Lutherans and Catholics in Dialogue)": 3.0},
#  'A.J. Chilson': {'Letters to Mickey': 5.0},
#  'A.J. Deus': {'Sacred Trust: The Medieval Church as an Economic Firm': 3.0,
#   'Textual Sources for the Study of Zoroastrianism': 1.0},
#  'A.J. Griffiths-Jones': {'Boudica and the Lost Roman': 4.0},
#  'A.J. Jr.': {'The Judgement of Jonah': 5.0,
#   'Roadside Crosses in Contemporary Memorial Culture': 5.0},
#  'A.J. Llewellyn': {'On a Bed of Rice': 4.0, 'Velocity: A Memoir': 5.0},
#  'A.J. Susmana': {'Understanding the Venezuelan Revolution: Hugo Chavez Talks to Marta Harnecker': 3.0,
#   "La vie n'est pas une foire nocturne": 5.0,
#   "It's Not an All Night Fair": 5.0},
#  'A.Jones': {'A Fierce Little Tragedy: Thought, Passion, and Self-Formation in the Philosophy Classroom': 5.0},
#  'A.K.': {'Lifting Belly': 4.0,
#   'The Book of Night with Moon (Cats of Grand Central, #1)': 3.0,
#   'The Book of Night with Moon (Cat Wizards, #1)': 3.0},
#  'A.K. Frailey': {'Charles the Second: King of England, Scotland, and Ireland': 4.0},
#  'A.L. Butcher': {'The Gates of Hell (Heroes in Hell, #2)': 4.0,
#   'The Gaston Leroux Bedside Companion': 4.0,
#   'The Golden Sword (Silistra #2)': 5.0},
#  'A.L. Scott': {'Gimme a Kiss / The Starlight Crystal / Bury Me Deep / The Phantom': 4.0},
#  'A.L. Sowards': {'The Last Escape: The Untold Story of Allied Prisoners of War in Europe 1944-45': 4.0,
#   'Cittadini In Uniforme': 4.0,
#   'Citizen Soldiers: The U S Army from the Normandy Beaches to the Bulge to the Surrender of Germany': 4.0,
#   'The White Rabbit: The Secret Agent the Gestapo Could Not Crack': 5.0,
#   'The Forgotten Few: The Polish Air Force in World War II': 4.0,
#   'Forgotten Few: Polish Air Force in the Second World War': 4.0,
#   'HMS Ulysses': 4.0,
#   'The First World War: The war to end all wars': 3.0,
#   'Citizen Soldiers: The U.S. Army from the Normandy Beaches to the Bulge to the Surrender of Germany, June 7, 1944 to May 7, 1945': 4.0,
#   'The U.S. Army from the Normandy Beaches to the Bulge to the Surrender of Germany: June 7, 1944-May 7, 1945': 4.0,
#   'Citizen Soldiers: The U. S. Army from the Normandy Beaches to the Bulge to the Surrender of Germany, June 7,1944 - May 7,1945': 4.0,
#   'Citizen Soldiers: From the Normandy Beaches to the Surrender of Germany': 4.0,
#   'Citizen Soldiers': 4.0,
#   'Citizen Soldiers: The U.S. Army from the Normandy Beaches to the Bulge to the Surrender of Germany June 7, 1944-May 7, 1945': 4.0,
#   'French Women and the First World War: War Stories of the Home Front': 3.0,
#   'And If I Perish: Frontline U.S. Army Nurses in World War II': 4.0,
#   'The Shetland Bus': 5.0,
#   'To Hell and Back': 5.0,
#   'To Hell And Back': 5.0,
#   'H.M.S. Ulysses': 4.0},
#  'A.L. Stumo': {'Spirituality & Health Care: Reaching Toward a Holistic Future': 3.0,
#   'Praying with Body and Soul': 4.0},
#  'A.L. Waddington': {"What They Didn't Teach You About the Civil War (What They Didn't Teach You (Paperback))": 4.0},
#  'A.M': {"Where's Mom Now That I Need Her?: Surviving Away from Home": 5.0},
#  'A.M.': {'Get Lucky!: Make Your Own Opportunities': 5.0,
#   'The House of Belonging': 5.0,
#   'Breathe! You Are Alive: Sutra on the Full Awareness of Breathing': 5.0},
#  'A.M. ': {'Blood Royal': 1.0},
#  'A.M. Heath': {'Ghost Writer': 5.0},
#  'A.R.': {'The Sorority: Samantha (Sorority Trilogy, #3)': 5.0,
#   'Monster: A Tale of Loch Ness': 5.0},
#  'A.R. Moler': {"Cat's Claw (Charlie Spotted Moon, #4)": 4.0},
#  'A.S Chambers': {'Night of the Jaguar (Stony Man, #31)': 5.0},
#  'A.S.F': {'Ideology in the Language of Judges: How Judges Practice Law, Politics, and Courtroom Control': 4.0},
#  'A.W': {'Image Bank to Accompany Neuroscience: Exploring the Brain': 5.0},
#  'A.W.': {'Ebony Angel': 5.0},
#  'A.d. Browne': {'The Colored Girl from Long Island: The Story of My Early Life': 3.0},
#  'A.i.sanchez': {'The Confessions: Selections from Books I-IX': 5.0,
#   'The Confessions of St. Augustine (Books One to Ten)': 5.0},
#  'A2': {'The Last Avant-Garde: The Making of the New York School of Poets': 5.0},
#  'AA': {'World of Ballet': 4.0},
#  'ABC': {'Lance Armstrong: The Race of His Life': 5.0,
#   "Babar's World Tour": 3.0,
#   "Fix it with Bob: Bob's Handy Hammer (Bob the Builder)": 1.0,
#   'Ramona the Brave (Ramona, #3)': 5.0,
#   'Beezus and Ramona (Ramona, #1)': 5.0,
#   'A Boy Called H: A Childhood in Wartime Japan': 5.0,
#   'Sex Games': 5.0,
#   'Henry and the Clubhouse': 5.0,
#   'Captain Underpants and the Perilous Plot of Professor Poopypants (Captain Underpants, #4)': 5.0,
#   'Pumpkin Moonshine': 4.0,
#   'Here We Go Round the Mulberry Bush': 4.0,
#   "It's Thanksgiving": 3.0,
#   'Beezus and Ramona': 5.0,
#   'Captain Underpants And The Perilous Plot Of Professor Poopypants: El Capitan Calzoncillos Y El Perverso Plan Del Profesor Pipcac': 5.0,
#   'Finding Little Sister': 4.0,
#   "Little Daruma and the Little Rabbits: A Japanese Children's Tale": 4.0,
#   'Ramona the Brave (Avon Camelot Books (Paperback))': 5.0,
#   'Ramona la Valiente': 5.0,
#   'Ramona The Brave': 5.0,
#   'Discover and Play: Pop Up Song Book (Baby Einstein)': 3.0,
#   'All Fall Down': 3.0,
#   'Happy Birthday, Baby Jesus': 3.0,
#   "My Name is Jojo (Jojo's Circus: Easy-to-Read, #1)": 3.0,
#   "Charlie Brown's Super Book of Questions and Answers about All Kinds of Animals ... from Snails to People!: Based on the Charles M. Schulz Characters": 4.0,
#   'People And Places: All Around The World': 3.0,
#   'Alvin Fernald, Superweasel': 4.0},
#  'ABHISHEK SINHA': {"Girish Karnad's Hayavadana: A Critical Study": 1.0},
#  'ABOOD': {'The Obligation Toward the Difficult Whole: Postmodernist Long Poems': 5.0},
#  'AC': {'Guerrillas': 4.0,
#   'Mao: A Life': 5.0,
#   'Flowers of Evil and Other Works/Les Fleurs du Mal et Oeuvres Choisies : A Dual-Language Book (Dover Foreign Language Study Guides) (English and French Edition)': 5.0,
#   'The Darling': 4.0,
#   'The Origins of the First World War': 5.0,
#   "Japan's Lost Decade: Origins, Consequences and Prospects for Recovery": 1.0,
#   'The Schirmer Inheritance': 4.0,
#   'Judgment on Deltchev': 5.0,
#   "The Dean's December": 5.0,
#   'European Universalism: The Rhetoric of Power': 1.0,
#   'The Judgment of Paris: The Revolutionary Decade That Gave the World Impressionism': 5.0,
#   'The Knights of Bushido: A Short History of Japanese War Crimes': 3.0,
#   'Picasso and Braque: Pioneering Cubism': 5.0,
#   'Henry Miller: The Paris Years': 4.0,
#   'Castle to Castle': 5.0,
#   'The Pisan Cantos': 5.0,
#   'Civilization and Capitalism 15th-18th Century, Vol. 1: The Structures of Everyday Life': 5.0,
#   'The Structures of Everyday Life': 5.0,
#   'The Structures of Everyday Life: Civilization and Capitalism 15th-18th Century, Volume 1': 5.0,
#   'The Passion of Michel Foucault': 5.0,
#   'Supreme Injustice': 5.0,
#   'Before the Dawn: Recovering the Lost History of Our Ancestors': 4.0,
#   'The Politics of Rich and Poor: Wealth and the American Electorate in the Reagan Aftermath': 4.0,
#   'Somebody Else: Arthur Rimbaud in Africa 1880-91': 3.0,
#   'The New Great Game: Blood and Oil in Central Asia': 5.0,
#   'The Nazi Dictatorship: Problems and Perspectives of Interpretation': 5.0,
#   'Der NS-Staat': 5.0,
#   "Plato's Theory of Knowledge: The Theaetetus and the Sophist": 5.0,
#   'Theaetetus/Sophist (Plato 7)': 5.0,
#   'The Man Who Knew Too Much: Hired to Kill Oswald and Prevent the Assassination of JFK': 4.0,
#   'Early Greek Poetry And Philosophy': 5.0,
#   'The Problem of Knowledge: Philosophy, Science and History Since Hegel': 5.0,
#   'Hitler and the Final Solution': 4.0,
#   'The Mediterranean and the Mediterranean World in the Age of Philip II, Volume I': 5.0,
#   'Before European Hegemony: The World System AD 1250-1350': 5.0,
#   'Phoenix: Fascism in Our Time': 4.0,
#   'Giovanni Gentile: Philosopher of Fascism': 5.0,
#   'Impressionism: Art, Leisure, and Parisian Society': 5.0,
#   'Dog Eat Dog': 4.0,
#   'Apartment in Athens': 5.0,
#   'The Treason of the Intellectuals': 1.0,
#   'Una Americana Consentida': 4.0,
#   'Desire and Delusion: Three Novellas': 4.0,
#   'The First Moderns: Profiles in the Origins of Twentieth-Century Thought': 4.0,
#   'A Season in Hell and Other Works/Une saison en enfer et oeuvres diverses ': 3.0,
#   'French Short Stories 1: Parallel Text': 4.0,
#   'The world at night': 5.0,
#   'Caravaggio': 3.0,
#   'Matisse (Basic Art S.)': 5.0,
#   'Walk the Dark Streets': 5.0,
#   "May '68 and Its Afterlives": 4.0,
#   'Guy Debord': 4.0,
#   'The Politics of Upheaval 1935-36 (The Age of Roosevelt, Vol 3)': 3.0,
#   'Gilded Gutter Life of Francis Bacon, The': 5.0,
#   'Henry James Short Stories': 5.0,
#   'The Politics of Illusion: The Fischer Controversy in German Historiography': 4.0,
#   'ReORIENT: Global Economy in the Asian Age': 1.0,
#   'Wall Street: How It Works And For Whom': 5.0,
#   'Wall Street': 5.0,
#   'The Weight of the Yen': 5.0,
#   'A Life of Picasso: 1907-1917: The Painter of Modern Life': 5.0,
#   'Paul Gauguin: 1848-1903 the Primitive Sophisticate': 5.0,
#   'Paul Gauguin, 1848-1903: The Primitive Sophisticate': 5.0,
#   "Plato's Theory of Knowledge: The Theatetus and the Sophist": 5.0,
#   'Bohemian Paris: Culture, Politics, and the Boundaries of Bourgeois Life, 1830-1930': 3.0,
#   'Alexandre Kojeve: The Roots of Postmodern Politics': 4.0},
#  'AC Fick': {'Margaret Atwood: Language, Text and System': 4.0,
#   'Een mond vol glas': 5.0,
#   'A Mouthful of Glass': 5.0,
#   'The Assassin: A Story of Race and Rage in the Land of Apartheid': 5.0},
#  'AC.': {'Poe, Death, and the Life of Writing': 4.0},
#  'ACE': {'Oracle9i JDBC Programming': 5.0},
#  'ACS Book-finder': {'Thanksgiving At Our House': 4.0,
#   'Go Away, Dark Night': 5.0},
#  'ACS Librarian': {'Missing the Piano': 3.0, 'Confess-O-Rama': 3.0},
#  'AD Meriem': {'Disaster! (Oxford Bookworms Factfiles: Stage 4: 1,400 Headwords)': 5.0},
#  'ADD': {'The War to Oust Saddam Hussein: Just War and the New Face of Conflict': 3.0,
#   'The Solar Electric House: Energy for the Environmentally-Responsive, Energy-Independent Home': 4.0},
#  'ADelicate': {'Goddesses and Wise Women: The Literature of Feminist Spirituality, 1980-1992: An Annotated Bibliography': 4.0},
#  'AE': {'My Secret Garden': 4.0,
#   'Dating For Dummies': 3.0,
#   'Pussy, King of the Pirates': 5.0,
#   'Cornel West: A Critical Reader': 5.0,
#   "It's Not the End of the World": 3.0,
#   'The Cornel West Reader': 5.0,
#   'The Last Days of MASH': 5.0,
#   'My Life as a Body': 5.0,
#   "My Secret Garden: Women's Sexual Fantasies": 4.0,
#   'Pussy': 5.0,
#   "Pagan Kennedy's Living: A Handbook for Aging Hipsters": 3.0,
#   'The Science of Sexy: Dress to Fit Your Unique Figure with the Style System that Works for Every Shape and Size': 3.0},
#  'AF': {"Everyday Etiquette:  Practical Advice for Social Situations at Home and on the Job (Emily Post's Essentials)": 4.0},
#  'AFSHIN heydarian': {'The Shah: The Glittering Story of Iran and Its People': 4.0},
# ...
#   'Written on Glass': 3.0,
#   'Early Pithouse Villages of the Mimbres Valley and Beyond: The McAnally and Thompson Sites in Their Cultural and Ecological Contexts': 3.0},
#  'Adri Guadron': {'Buddhism for Dummies': 4.0},
#  'Adri Sixto Lopez': {'Las Metamorfosis y Las Heroidas de Ovidio En La General Estoria de Alfonso El Sabio': 3.0},
#  'Adri Villegas': {'Las Aventuras de Tonino el Invisible': 3.0,
#   'La Cita Y Otros Cuentos De Mujeres Infieles': 5.0},
#  'Adria Irene': {'Rethinking Camelot: JFK, the Vietnam War and US Political Culture': 4.0},
#  'Adria Schoen': {"Toni's Crowd": 3.0},
#  'Adriaan Jansen': {'Leading the Revolution: How to Thrive in Turbulent Times by Making Innovation a Way of Life': 4.0},
#  'Adrian': {'The Ruby Programming Language': 5.0,
#   'Secrets of the Scorpion': 5.0,
#   'In The Presence Of The Enemy': 4.0,
#   'Orbit': 3.0,
#   'Orbit Can': 3.0,
#   'MySQL Phrasebook: Essential Code and Commands': 1.0,
#   'The Glorious Game: Extra Time: Arsene Wenger, Arsenal and the Quest for Success': 4.0,
#   'If You Survive': 5.0,
#   "If You Survive: From Normandy to the Battle of the Bulge to the End of World War II, One American Officer's Riveting True Story": 5.0,
#   'In the Presence of the Enemy (Inspector Lynley, #8)': 4.0,
#   'The Public Life of the Arts in America: The Public Life of the Arts in America, Revised Edition': 3.0,
#   'A History of Modern Russia: From Nicholas II to Vladimir Putin': 5.0,
#   'La justicia de los inocentes': 4.0,
#   'Robert Moses: Single-Minded Genius (Long Island Studies)': 4.0,
#   "Sonny's Blues": 5.0,
#   'If... Questions for Teens': 3.0,
#   'Brodie\'s Notes On Arthur Miller\'s "Crucible" (Brodies Notes)': 3.0,
#   'In the Presence of the Enemy (Inspector Lynley #8)': 4.0,
#   'E-Business 2.0: Roadmap for Success': 3.0,
#   "Someone Else's Daughter: The Life And Death Of Anita Cobby": 5.0,
#   'El Secreto de Dios': 5.0,
#   'London: An Architectural History': 3.0,
#   'Big Bird! - Modern Sightings of Flying Monsters': 4.0},
#  'Adrian  Starks': {'On Vital Reserves': 4.0},
#  'Adrian A.': {'Kanpai!: Volume 2': 4.0},
#  'Adrian Anderson': {'Diablo II: Official Strategy Guide (Bradygames Strategy Guides)': 3.0,
#   'Diablo II: Lord of Destruction Official Strategy Guide': 3.0,
#   'Textbook of Medical Physiology': 5.0,
#   'Review of Medical Physiology': 3.0,
#   'Review of Medical Physiology/Study Guide Included': 3.0,
#   '1989 Review Of Medical Physiology': 3.0,
#   'Review Of Medical Physiology': 3.0},
#  'Adrian Astur Alvarez': {'Moon In a Dewdrop: Writings of Zen Master Dogen': 5.0,
#   'Moon in a Dewdrop': 5.0,
#   'Chess Tactics': 4.0,
#   'The New Savory Wild Mushroom': 3.0,
#   "Fiction Writer's Workshop": 3.0},
#  'Adrian Avarvarei': {'Effective Listening': 1.0},
#  'Adrian Barrientos': {'Having a Life: Self-Pathology After Lacan': 3.0},
#  'Adrian Bolosin': {'How to Earn at Least $100,000 a Year in Network Marketing': 4.0,
#   'Joe Girard Complete Audio Box Set CD': 3.0},
#  'Adrian Brown Kuzel': {'Everything Happens to Aaron in the Summer': 5.0},
#  'Adrian Buck': {'Hume: The Arguments of the Philosophers': 4.0},
#  'Adrian Butler': {'Brandeis: Beyond Progressivism (American Political Thought)': 4.0},
#  'Adrian Colesberry': {'Incarnate Subject': 3.0,
#   'The Culture Cult: Designer Tribalism And Other Essays': 5.0,
#   'The Path of the Human Being: Zen Teachings on the Bodhisattva Way': 3.0,
#   'Heritage of the Conquistadors: Ruling Classes in Central America from Conquest to the Sandinistas': 4.0,
#   'Ghost Sonata/When We Dead Awaken: A Dramatic Epilogue in Three Acts': 5.0,
#   'Miss Julie and The Stronger': 5.0},
#  'Adrian Colley': {"The Longest Journey: The Inside Story Of Sussex's Championship Triumph": 3.0},
#  'Adrian Davis': {"Taran's Magic Sword: Taran and the Black Cauldron (Walt Disney: Golden Look Look Book)": 3.0},
#  'Adrian De Leon': {'Introduction to Linux: A Collection of Linux HOWTOs': 4.0},
#  'Adrian Espinosa': {'Encounters with Bigfoot': 5.0},
#  'Adrian Gheorghe': {'Life And Death In The Charity Ward': 4.0},
#  'Adrian Harper': {'Pens & Pencils': 4.0},
#  'Adrian Herbez': {'How the Leopard Changed Its Spots: The Evolution of Complexity': 3.0},
#  'Adrian Hoe': {'Sams Teach Yourself GIMP in 24 Hours': 3.0},
#  'Adrian Hyde': {'Die Wehrmacht: Volume One': 5.0},
#  'Adrian Lee': {'Bel Canto: A History of Vocal Pedagogy': 4.0,
#   'Bel Canto: a History of Vocal Pedagogy': 4.0},
#  'Adrian McCarthy': {'Game Programming Gems 2': 3.0},
#  'Adrian Mendizabal': {'Idea of Pure Critique': 4.0},
#  'Adrian Robbe': {'75 Years of the Oscar: The Official History of the Academy Awards': 5.0,
#   'The Big Picture: Money and Power in Hollywood': 5.0,
#   'Movie Awards: The Ultimate, Unofficial Guide to the Oscars, Golden Globes, Critics, Guild & Indie Honors': 5.0},
#  'Adrian Rose': {'Ancient Myths: Vivid Recreations of the Oldest Stories in the World...': 5.0},
#  'Adrian Rush': {'The Boomer Bible': 5.0},
#  'Adrian Smith': {"Jack Vance's The Excellent Prismatic Spray (Volume1:Issue 2)": 5.0},
#  'Adrian St': {'Note Speller Book 1 (Level 1)': 5.0},
#  'Adrian Stumpp': {"Please Don't Come Back from the Moon": 4.0,
#   'They Feed They Lion & The Names of the Lost: Two Books of Poems': 3.0},
#  'Adrian Vasquez': {'Aztec Art': 3.0},
#  'Adrian Velasquez': {'Tom Paine and Revolutionary America': 3.0},
#  'Adrian Verster': {'Distant Neighbors: A Comparative History of Seattle and Vancouver': 4.0},
#  'Adrian Watkins': {'Caught in Between: The Extraordinary Story of an Arab Palestinian Christian Israeli': 3.0},
#  'Adrian Wordz': {'How to Think & Reason in Macroeconomics': 5.0},
#  'Adrian Zatarain': {'Arcanos Negros de Hitler': 5.0},
#  'Adriana': {'The Fall of Advertising and the Rise of PR': 3.0,
#   'The Twelve Gifts of Birth': 5.0,
#   "No More Bull!: The Mad Cowboy Targets America's Worst Enemy: Our Diet": 4.0,
#   'The Piano Tuner': 5.0,
#   'The Mackenzies: Cleve (Mackenzies)': 3.0,
#   'Diario de la Rabia': 3.0,
#   'Typography 25': 5.0,
#   'The Land Beyond the Mountains (Kentuckians, #3)': 3.0,
#   "The Practical-Joke War (Disney's The Little Mermaid, #10)": 5.0,
#   'Catholic Study Bible-Nab': 5.0,
#   'The Catholic Study Bible': 5.0,
#   'Catholic Study Bible': 5.0,
#   "Type Rules!: The Designer's Guide to Professional Typography": 3.0,
#   'Tout Simenon, Tome 1': 4.0,
#   'Frida Intima': 1.0,
#   'Natacha': 5.0,
#   'Susan Sontag On Paul Goodman And The Dummy/1 Audio Cassette': 3.0,
#   'Whirlwind Courtship ': 1.0,
#   'Conversational Italian in 7 Days Package (Book + 2cds)': 3.0,
#   'The Most Wanted Bachelor': 1.0,
#   'La Caida de La Publicidad y Elauge de Las Rrpp: The Fall of Advertising and the Rise of PR': 3.0,
#   'The Mackenzies: Luke (Mackenzies)': 3.0,
#   'Ellis Island': 4.0,
#   'Spiritus': 4.0,
#   'One Wicked Night': 3.0,
#   'New Book Design': 4.0,
#   'Essential Japanese Grammar': 5.0,
#   'E, My Name Is Emily (My Name Is, #5)': 1.0,
#   'Kate Chopin Reconsidered: Beyond the Bayou': 3.0,
#   'El afinador de pianos': 5.0,
#   'Someone Like Him': 3.0,
#   'A Splintered Mirror: Chinese Poetry from the Democracy Movement': 3.0,
#   'Kiss of the Night Wind': 3.0,
#   'The Gift': 3.0,
#   'GLBTQ*: The Survival Guide for Queer & Questioning Teens': 3.0,
#   'From Function to Monument: Urban Landscapes of Roman Palestine, Syria, and Provincia Arabia': 3.0,
#   'Teach Me Hebrew: A Musical Journey Through the Day': 5.0},
#  'Adriana Diaz': {'Snowman: Fables and Fantasies': 4.0},
#  'Adriana Escobar': {'The Basenji: Out of Africa to You: A New Look': 5.0},
#  'Adriana Glackin': {'Dancing In The Streets': 4.0},
#  'Adriana Marquez': {'Kerala: A Magical Odyssey': 5.0},
#  'Adriana Moura': {'Michael Collins, Himself': 4.0},
#  'Adriana Noir': {'Flowers for Evelene': 4.0},
#  'Adriana Ruelas': {'Lo Sagrado En La Poesi&#X301;A De Jaime Sabines': 3.0},
#  'Adriana Scarpin': {'Le Camion; suivi de Entretien avec Michelle Porte': 4.0,
#   'What Lacan Said About Women': 5.0,
#   'Les Derniers Jours de Corinthe': 3.0,
#   'Judith Butler (Routledge Critical Thinkers)': 4.0},
#  'Adriane': {'Yellow Fever, Black Goddess: The Coevolution Of People And Plagues': 4.0,
#   'Down on My Knees': 5.0,
#   'Level 4: Virus Hunters of the CDC': 3.0,
#   'The Silver Kiss': 3.0,
#   'Girl Talk: Adolescent Magazines and Their Readers': 4.0,
#   'Life Lessons: Books of 1 & 2 Peter (Inspirational Bible Study; Life Lessons with Max Lucado)': 5.0},
#  'Adriane Devries': {"Dispossessed: Life in Our World's Urban Slums": 3.0,
#   'The Heart of the Artist: A Character-Building Guide for You and Your Ministry Team': 4.0,
#   'The Heart of Home Schooling: Teaching & Living What Really Matters': 3.0},
#  'Adrianna': {'Messiah': 5.0,
#   'The Englishwoman in Egypt': 3.0,
#   'A Lady, First': 3.0,
#   'Married Past Redemption (Sanguinet Saga, #7)': 4.0,
#   'The Lord and the Gypsy (Sanguinet Saga, #3)': 3.0},
#  'Adrianna Rondeau': {'Andrea Bocelli - Amore': 4.0},
#  'Adrianna Scibor': {'Museum Archives: An Introduction': 5.0},
#  'Adrianne': {'Hot Shoes: One Hundred Years': 5.0},
#  'Adrianne Loev': {'Grade Saver(Tm) Classic Notes Disgrace': 3.0},
#  'Adrianne Lucius': {'Springhouse Review for Critical Care Nursing Certification': 5.0},
#  'Adrianne Mathiowetz': {"The V Book: A Doctor's Guide to Complete Vulvovaginal Health": 5.0,
#   'The Collected Stories': 5.0},
#  'Adrianne Rosal': {'Triumph of the Imagination: The Story of Writer J. K. Rowling (Overcoming Adversity)': 5.0,
#   'R.L. Stine': 5.0},
#  'Adrianne S. Verry': {'Life After Death - Living Proof': 5.0},
#  'Adriano': {'Dr. Moritz (Don Mauricio) Hochschild, 1881-1965: The Man and His Companies: A German Jewish Mining Entrepreneur in South America': 4.0},
#  'Adriano Vretaros': {'Designing Resistance Training Programs - 3rd': 4.0},
#  'Adrianus Yoga': {'Director MX 2004 Games: Game Development with Director [With CDROM]': 3.0},
#  'Adrie Lily': {'Understanding Your Temperament: A Self-Analysis With a Christian Viewpoint With Temperament Inventory Scoring Templates': 5.0},
#  'Adriel': {'Plato Unmasked: The Dialogues Made New': 5.0},
#  'Adrielle': {'Arts with the Brain in Mind': 5.0,
#   'Jesus Freaks: Stories of Revolutionaries Who Changed Their World: Fearing God, Not Man': 5.0},
#  'Adrien Grandemange': {'"Si C\'est Un Homme" (1947), Primo Levi': 3.0},
#  'Adrien Green': {'Philosophy of Religion: An Anthology': 5.0},
#  'Adrien Stoloff': {'The Weight of the Past: Living with History in Mahajanga, Madagascar': 5.0},
#  'Adriene Baron Tacla': {'Pytheas of Massalia: On the Ocean : Text, Translation and Commentary': 3.0},
#  'Adrienna': {'Life and Def: Sex, Drugs, Money, + God': 4.0,
#   'Jezebel Spirit': 5.0,
#   'Deborah': 4.0,
#   'Cite It Right: The SourceAid LLC Guide to Citation, Research, and Avoiding Plagiarism': 4.0,
#   'The Milkweed Prophesy: Epitaph Of The Apocalypse': 3.0,
#   'Keeping the Faith: Stories of Love, Courage, Healing, and Hope from Black America': 3.0,
#   'Nonlegal Careers for Lawyers': 5.0,
#   'Keeping the Faith: Stories of Love, Courage, Healing and Hope from Black America': 3.0,
#   'How to Write a Selling Screenplay': 4.0,
#   'Master the Civil Service Exam, 3rd Edition': 4.0,
#   'Inner City Miracle': 5.0,
#   'Getting Permission: How To License & Clear Copyrighted Materials Online & Off': 4.0,
#   'Make Your Paycheck Last: How to Create a Budget You Can Live with': 3.0,
#   "What to Expect When Mommy's Having a Baby": 5.0,
#   'Inside Power': 3.0,
#   'God Is More than Enough (LifeChange Books)': 3.0,
#   'Lower Your Taxes - Big Time!: Wealth-Building, Tax Reduction Secrets from an IRS Insider': 4.0,
#   'Lower Your Taxes - Big Time!': 4.0,
#   'The Wayans Brothers': 3.0,
#   'Friends, Lovers, and Soulmates: A Guide to Better Relationships Between Black Men and Women': 3.0,
#   'Walking in Your Destiny: How to Receive Your Spiritual Inheritance Now': 3.0,
#   'The Threshing Floor: How to Know Without a Doubt that God Hears Your Every Prayer': 4.0},
#  'Adrienne': {'Making the Cat Laugh': 4.0,
#   "You Don't Know Jack (NY Girlfriends, #2)": 4.0,
#   'The Passionate Olive: 101 Things to Do with Olive Oil': 4.0,
#   'All the Trouble in the World ': 5.0,
#   "Fool's Fate (Tawny Man, #3)": 5.0,
#   'Extreme Passions (Erotic Interludes, #4)': 4.0,
#   'Daring to Be Bad: Radical Feminism in America, 1967-1975': 5.0,
#   'The Reward (Malloy Family, #3)': 4.0,
#   "Sidewalk Critic: Lewis Mumford's Writings on New York": 4.0,
#   "Churchill's Black Dog and Other Phenomena of the Human Mind": 4.0,
#   "Churchill's Black Dog, Kafka's Mice, and Other Phenomena of the Human Mind": 4.0,
#   'Fear of Intimacy': 5.0,
#   'All The Trouble In The World': 5.0,
#   'All Troubles In World (A Format)': 5.0,
#   "Caesar's Civil War": 5.0,
#   'The Memory Book': 1.0,
#   'Birds/Lysistrata/Assembly-Women/Wealth': 3.0,
#   'On the Bus: The Legendary Trip of Ken Kesey and the Merry Pranksters': 3.0,
#   'Corporate Storytelling: Planning and Creating Internal Communications': 4.0,
#   'Science of Poker': 5.0,
#   'Perfect Practice: Or Chunks, Clumps, Hunks, Clods Blocks, Slivers, Slices, And Globs (Art Of Piano Performance)': 4.0,
#   '16 Ways to Love Your Lover': 5.0,
#   'Antarctica: Journey to the South Pole': 4.0,
#   'Economics of Women, Men, and Work': 3.0,
#   'Understanding Psychological Assessment': 4.0,
#   'Beneath the Metropolis: The Secret Lives of Cities': 3.0,
#   "You Can't Take It With You! All About the Preparation of Individual Wills, and Full Attention to Taxes, Probates, and Trusts": 3.0,
#   'More Than You Know': 5.0,
#   'Burning Bright': 4.0,
#   "100 Top Picks for Homeschool Curriculum: Choosing the Right Educational Philosophy for Your Child's Learning Style": 3.0,
#   'Stories Trainers Tell: 55 Ready-To-Use Stories to Make Training Stick': 3.0,
#   'Children of the Albatross (Cities of the Interior #2)': 4.0,
#   'Absent in the Spring': 4.0,
#   'Fanny Burney: The Mother of English Fiction': 4.0,
#   'Doghouse To Dollar$ Workbook: Turn "Yucks Into Bucks" Investor\'s Guide': 5.0,
#   'Wolfgang Amadeus Mozart: A Biography': 3.0,
#   'Art From Many Hands: Multicultural Art Projects Revised Expanded Edition': 4.0,
#   'The Well-Ordered Home: Organizing Techniques for Inviting Serenity Into Your Life': 3.0,
#   'Workhorse of the Western Front: The Story of the 30th Infantry Division': 5.0,
#   'Malorie Blackman Biography': 4.0,
#   'Beauty Up: Exploring Contemporary Japanese Body Aesthetics': 5.0,
#   'Buried in So Sweet a Place': 4.0,
#   'Black Students. Middle Class Teachers.': 1.0,
#   'The Paradox of Change: American Women in the 20th Century': 5.0},
#  'Adrienne ': {'The Newborn Christian: 114 Readings from J. B. Phillips': 5.0},
#  'Adrienne Bagnato': {'Worth a Thousand Words: An Annotated Guide to Picture Books for Older Readers': 5.0},
#  'Adrienne Furness': {"Everything's Coming Up Sock Monkeys!: Art, History and Business of the American Sock Monkey": 3.0},
#  'Adrienne Girard': {"Men May Come and Men May Go, But I've Still Got My Little Pink Raincoat: Life and Love in and Out of My Wardrobe": 3.0},
#  'Adrienne Kangas': {"Pat the Bunny Baby's First Year with Gifts (Pat the Bunny)": 3.0},
#  'Adrienne Kiser': {"The Metamorphosis of Baubo: Myths of Woman's Sexual Energy": 5.0,
#   'Letters to J. D. Salinger': 4.0,
#   'Habeas Codfish: Reflections on Food and the Law': 5.0},
#  'Adrienne Kravchak': {'Once A Wolf: How Wildlife Biologists Fought to Bring Back the Gray Wolf': 5.0},
#  'Adrienne Lusk fiedler': {'The Jews of New Amsterdam': 5.0},
#  'Adrienne Muller': {'3 Culinary Mysteries': 5.0,
#   '3 Culinary Mysteries: An Audio Book Trilogy Of Best Sellers:  Dying For Chocolate/Catering To Nobody/The Last Suppers': 5.0},
#  'Adrienne Reed': {"What's a Woman to Do?": 5.0},
#  'Adrienne Salabert': {'Milwaukee Then and Now': 4.0},
#  'Adrienne Stapleton': {'Realism and the Aim of Science': 4.0,
#   'Realism and the Aim of Science: From the PostScript to the Logic of Scientific Discovery': 4.0},
#  'Adrienne Testa': {'Misery Loves Maggody (Arly Hanks, #11)': 3.0},
#  'Adrienne deWolfe': {'Nature-Speak: Signs, Omens and Messages in Nature': 5.0},
#  'Adrik Kemp': {'Lizzie': 4.0},
#  'Adrillew': {'K2-Dreams and Reality': 4.0},
#  'Adriste Judan': {'Dr Jeremys Wife': 5.0},
#  'Adrith Bicchieri': {'Pizza! (Pizza): Deliciosas recetas para hacer basos y cubiertas para los amantes de la pizza': 3.0},
#  'Adroit': {'Cremaster 1': 4.0},
#  ...}

# %% [markdown]
# <u>Note</u> that you may run into an error stating that "IOPub data rate exceeded", you can solve this issue [here](https://stackoverflow.com/questions/43288550/iopub-data-rate-exceeded-in-jupyter-notebook-when-viewing-image).
#
# Now that we finished cleansing, analyzing and preparing our data, we will build a function to run our model.

# %% [markdown]
# # Modeling

# %% [markdown]
# The model we are using to determine similarities betweens users is the Euclidean Distance Model, which measures the distance between users, and takes the closest distance for similarity considerations.
#
# Here is the formula that we are going to use:
#
#     dist((x,y),(a,b)) = √(x - a)² + (y - b)²
#
# First we will create a "sim_distance" function by implementing the Euclidean Distance formula between two users. We will also add the results by 1 and then divide it by 1 so the Euclidean Score is between 0 to 1.
#
# Next, we will create a "top_matches" function while also using the "sim_distance" function to determine the list of all other users who are similar to "Maureen". This is also where we are able to find the Euclidean Distance between "Maureen" and other users without manually finding two users that rated the same book.
#
# Finally, we will put everything together and create a "get_recommendations" function as our recommendation system. To create our recommendation system, we will use the following approach:
# - Firstly, we will calculate the similarity score between all users that are closest to "Maureen" using the "sim_distance" function, this will provide us with a similarity score for each user that is similar to "Maureen"
# - Secondly, we will take the similarity score of each user and multiply it by the book rating for the same user on a book which "Maureen" has yet to rate
# - Now, we have a obtained a new value called rated similarity score for each user
# - Thirdly, we will add the rated similarity score for all users as our sum of rated similarity score, and also add the similarity score for all users as our sum of similarity score
# - Fourthly, we will divide the sum of rated similarity score by the sum of similarity score to determine the recommended rating that "Maureen" would prefer on the specific book that was rated by all other users which "Maureen" has yet to rate
#
#
# We will repeat this process for each book in our "get_recommendations" function for predicting and recommending similar books that "Maureen" is interested in.

# %%
# returns a distance-based similarity score for person1 and person2
def sim_distance(prefs,person1,person2):
    # get the list of shared_items
    si = {} 
    for item in prefs[person1]:
        if item in prefs[person2]:
            si[item]=1
    
    # if they have no ratings in common, return 0
    if len(si) == 0: 
        return 0
    
    # add up the squares of all the differences
    sum_of_squares = sum([pow(prefs[person1][item] - prefs[person2][item],2) 
                          for item in prefs[person1] if item in prefs[person2]])
    
    return 1/(1+sum_of_squares)


# checks for similarity to myself (Maureen) using Euclidean distance score
# n is the length of shared items si
def top_matches(prefs, person, n=10, similarity = sim_distance):
    # sets other parameter to exclude myself
    scores = [(similarity(prefs,person,other), other)
            for other in prefs if other!=person]
    
    # sort the list so the higest score appear at the top
    scores.sort()
    scores.reverse()
    return scores[0:n] # slices from first index to last index


# Gets recommendation for a person by using a weighted average of all other users
# Using Euclidean distance score
def get_recommendations(prefs, person, similarity = sim_distance):
    totals = {} 
    # get the list of each book for sum of similarity score x actual rating
    simSums = {} # get the list of each book for sum of similartiy score
    for other in prefs:
        # don't compare me to myself
        if other == person:
            continue
        sim = similarity(prefs, person, other) # then use sim
        
        # ignore scores of zero or lower
        if sim <= 0:
            continue
        for item in prefs[other]: # item in prefs from sim_distance
            
            # only score books I haven't seen yet
            if item not in prefs[person] or prefs[person][item] == 0:
                # similarity * score
                totals.setdefault(item,0) 
                totals[item] += prefs[other][item] * sim
                # sum of similarities
                simSums.setdefault(item,0)
                simSums[item] += sim
            # setdefault calls the key, and returns 0 if it does not exist
            # similar to get()
            
    # create the normalized list
    rankings = [(total/simSums[item], item) for item, total in totals.items()]
    # total(singular item, sum of (sim*actual ratings for each user)),
    # divide by simSum for each item,
    # and run total and item for each item, 
    # while adding each result in the totals list,
    # then returns a dictionary by calling totals.items()
    # items() returns a list of dictionary
    
    # return the sorted list
    rankings.sort()
    rankings.reverse()
    return rankings

# %% [markdown]
# # Similar Users and Recommendation

# %%
# top 10 similar users to Maureen
top_matches(d, 'Maureen', n=10)
# Out:
# [(1.0, 'Sebastienne Rimbaud'),
#  (1.0, 'Karol'),
#  (1.0, 'Jonathan'),
#  (1.0, 'Ahmad Sharabiani'),
#  (0.5, 'Jeffrey Keeten'),
#  (0.5, 'Herb'),
#  (0.5, 'Brian'),
#  (0.5, 'Brenda'),
#  (0.5, 'Bobby Sterr'),
#  (0.2, 'Marcy')]

# %%
# top recommendation for Maureen
get_recommendations(d, 'Maureen', similarity = sim_distance)
# Out:
# [(5.0, 'the story of panda bears'),
#  (5.0, 'Your Secrets Sleep With Me'),
#  (5.0,
#   "You Wouldn't Want to Work on the Great Wall of China!: Defenses You'd Rather Not Build"),
#  (5.0, 'Yoga For Children: A Complete Illustrated Guide to Yoga'),
#  (5.0,
#   'Writing Security: United States Foreign Policy and the Politics of Identity'),
#  (5.0, "Writer's Workshop: Writing Skills and Activities, Grades 4-6"),
#  (5.0, 'World of the Thibaults'),
#  (5.0, 'Words for a Deaf Daughter and Gala: A Fictional Sequel'),
#  (5.0, 'Word Family Mini-Storybooks: Grades 1-3'),
#  (5.0, 'Wonderland Avenue'),
#  (5.0, 'Wolf Willow'),
#  (5.0, 'Wizard Of The Dome: R. Buckminster Fuller, Designer For The Future'),
#  (5.0, 'Wittgenstein: The Terry Eagleton Script and the Derek Jarman Film'),
#  (5.0, 'Windriders of the Jagged Cliffs'),
#  (5.0,
#   "William of Malmesbury's Chronicle of the Kings of England: From the Earliest Period to the Reign of King Stephen"),
#  (5.0, 'Wife to Mr. Milton: The Story of Marie Powell'),
#  (5.0, 'Why Paint Cats: The Ethics of Feline Aesthetics'),
#  (5.0, "Walt Whitman's America"),
#  (5.0, 'Walking with the Wind'),
#  (5.0, "Vanity Fair: Bringing Thackeray's Timeless Novel to the Screen"),
#  (5.0, 'Under Fire'),
#  (5.0,
#   'Unadjusted Man in the Age of Overadjustment: Where History and Literature Intersect'),
#  (5.0, 'Una paz  solo nuestra'),
#  (5.0, 'Un Agent Qui Vous Veut Du Bien'),
#  (5.0, 'Typography 26: The Annual of the Type Directors Club'),
#  (5.0, 'Twelve Years a Slave. Narrative of Solomon Northup'),
#  (5.0, 'Twelve Years a Slave'),
#  (5.0, 'Twelve Years A Slave: Excerpts From The Narrative Of Solomon Northup'),
#  (5.0, 'Tropico de Capricornio'),
#  (5.0, 'Tropic of Capricorn'),
#  (5.0, 'Tropic Of Capricorn'),
#  (5.0, 'Tremor of Intent'),
#  (5.0, 'Tremor Of Intent'),
#  (5.0, 'Tome of Salvation: Priests of the Old World'),
#  (5.0, 'Tohtori Jekyll ja Mr. Hyde'),
#  (5.0, 'Todas las almas'),
#  (5.0, 'Tinker, Tailor, Soldier, Spy'),
#  (5.0, 'Tinker Tailor Soldier Spy'),
#  (5.0, 'Timely Themes from Astronauts to Whales for Grades 4-6'),
#  (5.0, 'Time, Narrative, and History'),
#  (5.0, 'Three Tragedies: Antigone, Oedipus the King & Electra'),
#  (5.0, 'Thoughts of a Philosophical Fighter Pilot'),
#  (5.0, 'Thinner'),
#  (5.0, "Thief Lord ('El Senor De Los Ladrones)"),
#  (5.0, 'The Works of Plato'),
#  (5.0, 'The Woman in the Fifth'),
#  (5.0, "The Wind's Twelve Quarters"),
#  (5.0, 'The Way We Live Now'),
#  (5.0, 'The Wave'),
#  (5.0, "The Water's Footfall and The Green Volume"),
#  (5.0, "The Water's Footfall"),
#  (5.0, 'The War for Korea, 1945-1950: A House Burning'),
#  (5.0, 'The Walled Garden of Truth'),
#  (5.0, "The Wallace 'N Ladmo Show Presents Aunt Maud's Storybook"),
#  (5.0, 'The Wall (Pink Floyd)'),
#  (5.0, 'The Voice in the Closet'),
#  (5.0, 'The Violet Hour'),
#  (5.0, 'The Unknown Soldiers: African-American Troops in World War I'),
#  (5.0, 'The Unfinished System of Nonknowledge'),
#  (5.0,
#   'The Unadjusted Man: A New Hero for Americans: Reflections on the Distinction Between Conforming and Conserving'),
#  (5.0, 'The Tin Box'),
#  (5.0, 'The Thief Lord'),
#  (5.0, 'The Thibaults'),
#  (5.0, 'The Tales of Edgar Allan Poe (SAT Score-Raising)'),
#  (5.0, 'The Stream of Life'),
#  (5.0, 'The Strange Case of Dr. Jekyll and Mr. Hyde'),
#  (5.0, 'The Strange Case of Dr. Jekyll And Mr Hyde'),
#  (5.0, 'The Strange Case of Dr Jekyll and Mr Hyde '),
#  (5.0, 'The Strange Case of Dr Jekyll and Mr Hyde'),
#  (5.0, 'The Stones of Summer'),
#  (5.0, 'The Slynx'),
#  (5.0, 'The Slightly Irregular Fire Engine'),
#  (5.0, 'The Silva Mind Control Method for Getting Help from Your Other Side'),
#  (5.0, 'The Shooting Star (Tintin, #10)'),
#  (5.0, 'The Shooting Star (The Adventures of Tintin)'),
#  (5.0, 'The Sheltering Sky'),
#  (5.0, 'The Shadow Over Innsmouth'),
#  (5.0, 'The Sagas of Icelanders'),
#  (5.0, "The Rose Garden (The Gulistan) of Shekh Muslihu'd-Din Sadi of Shiraz"),
#  (5.0, 'The Rose Garden (Gulistan) of Saadi'),
#  (5.0, 'The Red Sea Sharks (Tintin, #19)'),
#  (5.0, 'The Red Sea Sharks (Adventures Of Tintin)'),
#  (5.0, 'The Red Sea Sharks'),
#  (5.0, 'The Radetzky March'),
#  (5.0, 'The President'),
#  (5.0, 'The Powers That Be'),
#  (5.0, 'The Poems of Hafez'),
#  (5.0, 'The Poems & Sonnets of William Shakespeare  '),
#  (5.0, 'The Pleasures of Philosophy'),
#  (5.0,
#   'The Photoshop CS2 Speed Clinic: Automating Photoshop to Get Twice the Work Done in Half the Time'),
#  (5.0, 'The Pentagon of Power (The Myth of the Machine, Vol 2)'),
#  (5.0, 'The Penguin Guide to Jazz Recordings'),
#  (5.0, 'The Parker Grey Show'),
#  (5.0, 'The Oxford Companion to the Brontes'),
#  (5.0, 'The Other'),
#  (5.0,
#   "The Origins of the Eisenhower Doctrine: The US, Britain and Nasser's Egypt, 1953-57"),
#  (5.0, 'The Moviegoer'),
#  (5.0, 'The Minotaur Takes A Cigarette Break'),
#  (5.0, 'The Ministry of Fear'),
#  (5.0, 'The Meaning of Night'),
#  (5.0, "The Mathnawi of Jalalu'ddin Rumi, Vol 5, Persian Text"),
#  (5.0,
#   'The Mathnawi Of Jalaluddin Rumi (5 Volume Set/ Translation & Commentary)'),
#  (5.0, 'The Martial Arts Student Log Book'),
#  (5.0, 'The Man Who Went Up in Smoke'),
#  (5.0, 'The Man Who Went Up In Smoke'),
#  (5.0,
#   'The Making of Modern Iran: State and Society Under Riza Shah 1921-1941'),
#  (5.0, 'The Lottery: And Other Stories'),
#  (5.0, 'The Lottery and Seven Other Stories'),
#  (5.0, 'The Lottery and Other Stories (Modern Library)'),
#  (5.0, 'The Lottery and Other Stories'),
#  (5.0, 'The Lost Angel'),
#  (5.0, 'The Little Matchgirl And Other Stories'),
#  (5.0, 'The Little Drummer Girl'),
#  (5.0, 'The Little Black Fish and Other Modern Persian Stories'),
#  (5.0, 'The Little Black Fish Off to See the World'),
#  (5.0, 'The Little Black Fish'),
#  (5.0, 'The Library at Night'),
#  (5.0, 'The Leopard'),
#  (5.0, 'The Last of the Just'),
#  (5.0, 'The Last Generation of the Roman Republic'),
#  (5.0, 'The Lady With the Little Dog and Other Stories, 1896-1904'),
#  (5.0, 'The Killing Star'),
#  (5.0,
#   'The Killer Angels: A Novel of the Civil War (The Civil War Trilogy, #2)'),
#  (5.0, 'The Killer Angels (The Civil War Trilogy, #2)'),
#  (5.0, 'The Killer Angels'),
#  (5.0, 'The Jewel in the Crown (The Raj Quartet, #1)'),
#  (5.0, 'The Iliad/The Odyssey'),
#  (5.0, 'The Iliad & the Odyssey'),
#  (5.0, 'The Iliad & The Odyssey (Boxed Audio)'),
#  (5.0, 'The Iliad & The Odyssey'),
#  (5.0, 'The Human Stain (The American Trilogy, #3)'),
#  (5.0, 'The Hours'),
#  (5.0, 'The Heat of the Moon (Rachel Goddard Mystery #1)'),
#  (5.0,
#   'The Hearts of Darkness: How White Writers Created the Racist Image of Africa'),
#  (5.0, 'The Hawk is Dying'),
#  (5.0,
#   'The Hafez Poems of Gertrude Bell: With the Original Persian on the Facing Page'),
#  (5.0, "The Gulistan (Rose Garden) of Sa'di"),
#  (5.0, 'The Greek Way of Death: Jealousy in Literature'),
#  (5.0, 'The Greek Way of Death'),
#  (5.0, 'The Gift: Novel'),
#  (5.0, 'The Gift by H.D.: The Complete Text'),
#  (5.0, 'The Ghosts of Iwo Jima'),
#  (5.0, 'The Garden of Heaven: Poems of Hafiz'),
#  (5.0, 'The Gambler (Hesperus Classics Series)'),
#  (5.0, 'The Gambler'),
#  (5.0, 'The Forging of the American Empire (Human Security)'),
#  (5.0, 'The Forging of the American Empire'),
#  (5.0, 'The Forest of Twisted Dreams (Wizards, Warriors and You, #1)'),
#  (5.0, 'The Fall of the House of Usher'),
#  (5.0, 'The Fables of Aesop'),
#  (5.0, 'The Evolution of Gryphaea'),
#  (5.0, 'The Essential Dr. Jekyll & Mr. Hyde'),
#  (5.0, 'The Enemy Within: The Secret War Against the Miners'),
#  (5.0,
#   'The End of the Line: How Overfishing Is Changing the World and What We Eat'),
#  (5.0,
#   'The Divan-I-Hafiz (Classics of Persian Literature, 3) (Classics of Persian Literature, 3)'),
#  (5.0, 'The Divan Of Hafiz English Persian'),
#  (5.0, 'The Divan'),
#  (5.0, 'The Dead Father (FSG Classics)'),
#  (5.0, 'The Dead Father'),
#  (5.0, 'The Dark Side of the Moon: The Making of the Pink Floyd Masterpiece'),
#  (5.0, 'The Crescent Moon'),
#  (5.0, 'The Courage to Teach, a Guide for Reflection and Renewal'),
#  (5.0, 'The Confessions of Jean Jacques Rousseau 1'),
#  (5.0, 'The Confessions of J.J. Rousseau'),
#  (5.0, 'The Confessions 1'),
#  (5.0,
#   'The Complete Novels: Voyage in the Dark / Quartet / After Leaving Mr Mackenzie / Good Morning, Midnight / Wide Sargasso Sea'),
#  (5.0,
#   'The Complete Lean Enterprise: Value Stream Mapping for Administrative and Office Processes'),
#  (5.0, 'The Complete Fables'),
#  (5.0,
#   'The Complete Book of Tai Chi Chuan: A Comprehensive Guide to the Principles and Practice'),
#  (5.0, 'The Cold Dish (Walt Longmire, #1)'),
#  (5.0, 'The Classic Treasury of Hans Christian Andersen'),
#  (5.0, 'The Civil Wars'),
#  (5.0, 'The Civil War: A Narrative: Vol. 2: Fort Donelson to Memphis'),
#  (5.0, 'The Civil War: A Narrative, Volume 4: Second Menassas to Pocotaligo'),
#  (5.0, "The Captain's Verses (Spanish Edition)"),
#  (5.0, "The Captain's Verses"),
#  (5.0, 'The Cambridge Companion to Camus'),
#  (5.0, 'The Breaking Point: Sedan and the Fall of France, 1940'),
#  (5.0, 'The Boys of Summer'),
#  (5.0, 'The Book of Fables'),
#  (5.0,
#   "The Best of Uncle John's Bathroom Reader (Uncle John's Bathroom Reader Series)"),
#  (5.0, 'The Art of Warcraft'),
#  (5.0, 'The American Dream: A Short History of an Idea That Shaped a Nation'),
#  (5.0, 'The Agony and the Ecstasy: A Biographical Novel of Michelangelo'),
#  (5.0, 'The Agony and the Ecstasy  '),
#  (5.0, 'The Agony and the Ecstasy'),
#  (5.0,
#   'The Age of Economists: From Adam Smith to Milton Friedman (Chapion of Freedom Series)'),
#  (5.0, 'The Adventures of Tintin: Cigars of the Pharaoh (Tintin, #4)'),
#  (5.0, 'The 900 Days: The Siege of Leningrad'),
#  (5.0, 'The 42nd Parallel (U.S.A., #1)'),
#  (5.0, "Teacher's Messages and Notes Home: Grades 2-6"),
#  (5.0,
#   'Taipan: Una Encrucijada De Razas. Un Hervidero De Pasiones. Una Ciudad Fascinante: Hong Kong'),
#  (5.0, 'Tai-Pan (Asian Saga, #2)'),
#  (5.0, 'Tai-Pan'),
#  (5.0, 'Tai- Pan. Roman.'),
#  (5.0, 'Tai Pan'),
#  (5.0, 'Suvashun'),
#  (5.0, 'Suttree'),
#  (5.0, 'Summer Love (Camp Girl-Meets-Boy, #1)'),
#  (5.0, 'Strange Case of Dr. Jekyll and Mr. Hyde'),
#  (5.0, 'Stormy Weather / Lucky You'),
#  (5.0, "Storming Heaven's Gate: An Anthology of Spiritual Writings by Women"),
#  (5.0, 'Stoner'),
#  (5.0, 'Steal This Book Too!'),
#  (5.0, 'Stars in Their Courses: The Gettysburg Campaign, June-July 1863'),
#  (5.0, 'Stars in Their Courses'),
#  (5.0, 'Spring Snow'),
#  (5.0, 'Solon the Thinker: Political Thought in Archaic Athens'),
#  (5.0,
#   "Soldier's Heart: Being the Story of the Enlistment and Due Service of the Boy Charley Goddard in the First Minnesota Volunteers"),
#  (5.0,
#   'Sobre la Teoria de la Relatividad Especial y General (Ciencia y Tecnica)'),
#  (5.0, 'Smoke Signals: A Screenplay'),
#  (5.0, 'Smart Moves: Why Learning Is Not All in Your Head'),
#  (5.0, 'Sleeping Beauty: a Little Golden Book (Disney Princess)'),
#  (5.0, 'Simplicity'),
#  (5.0, 'Simenon: A Biography'),
#  (5.0, 'Silences'),
#  (5.0, 'Shunju: New Japanese Cuisine'),
#  (5.0, 'Sherlock Holmes Short Stories'),
#  (5.0, "Shakespeare's Sonnets and Poems (Folger Shakespeare Library)"),
#  (5.0, "Shakespeare's Sonnets  Poems"),
#  (5.0, 'Shakespeare After All'),
#  (5.0, 'Sexual Practices and the Medieval Church'),
#  (5.0,
#   "Self-Esteem and Adjusting with Blindness: The Process of Responding to Life's Demand"),
#  (5.0, 'Self-Esteem and Adjusting with Blindness'),
#  (5.0, 'Selected Poems and Prose of Paul Celan'),
#  (5.0, 'Selected Poems'),
#  (5.0, 'Second Helpings Please!'),
#  (5.0,
#   'Search For Modern Nationalism: Zhang Binglin And Revolutionary China, 1869 1936'),
#  (5.0, "Science and Providence: God's Interaction with the World"),
#  (5.0, 'Savushun: A Novel About Modern Iran '),
#  (5.0, 'Samuel David Luzzatto, traditionalist scholar'),
#  (5.0, 'Saints and Villains'),
#  (5.0, 'Sacred and Profane: A Novel of the Life and Times of Mozart'),
#  (5.0, "Russia's First Modern Jews: The Jews of Shklov"),
#  (5.0, "Rumi's Daughter"),
#  (5.0, 'Rufus M.'),
#  (5.0, 'Rue des boutiques obscures'),
#  (5.0, 'Rue des Boutiques Obscures'),
#  (5.0, 'Rudin'),
#  (5.0, 'Rosencrantz and Guildenstern are Dead'),
#  (5.0, 'Rosencrantz and Guildenstern Are Dead'),
#  (5.0,
#   'Rosencrantz & Guildenstern are Dead: A Play in Three Acts (Favorite Broadway Dramas)'),
#  (5.0, 'Rommel Drives on Deep Into Egypt'),
#  (5.0, 'Robert Louis Stevenson: A Biography'),
#  (5.0, 'Rimbaud: Complete Works, Selected Letters'),
#  (5.0, 'Rimbaud Complete'),
#  (5.0, "Restoring North America's Birds: Lessons from Landscape Ecology"),
#  (5.0, 'Reporting World War II Vol. 1: American Journalism 1938-1944'),
#  (5.0,
#   'Relativity: The Special and the General Theory: The Masterpiece Science Edition'),
#  (5.0, 'Relativity: The Special and the General Theory'),
#  (5.0, 'Relativity: The Special and General Theory'),
#  (5.0,
#   "Reflections on the Dawn of Consciousness: Julian Jaynes's Bicameral Mind Theory Revisited"),
#  (5.0, 'Rashomon: Akira Kurosawa, Director'),
#  (5.0, 'Rashomon: A Film'),
#  (5.0, 'Rashomon (Film Focus)'),
#  (5.0, 'Ramsey Campbell, Probably: On Horror and Sundry Fantasies'),
#  (5.0, 'Rain Man'),
#  (5.0, 'Radetzkymarsch: Roman'),
#  (5.0, 'Radetzkymarsch '),
#  (5.0, 'Radetzkymarsch'),
#  (5.0, 'ROSENCRANTZ & GILDENSTERN ARE DEAD'),
#  (5.0, 'Quick and Easy Math for Grades 3-6'),
#  (5.0,
#   'Qand va namak: Zarb al-masalha-yi Tihrani bih zaban-i muhavarah, ba tajdid-i nazar-i kamil'),
#  (5.0, 'Pushed (Hardy Boys: Undercover Brothers, #18)'),
#  (5.0, "Propaganda: The Formation of Men's Attitudes"),
#  (5.0,
#   'Powershift: Knowledge, Wealth, and Violence at the Edge of the 21st Century'),
#  (5.0,
#   'Powershift: Knowledge, Wealth, and Power at the Edge of the 21st Century'),
#  (5.0, 'Poetry Plus!: Grades K-6'),
#  (5.0, 'Poems of Paul Celan'),
#  (5.0, "Plutarch's Lives"),
#  (5.0, 'Pigeons on the Grass'),
#  (5.0, 'Pied Piper'),
#  (5.0, 'Petersburg'),
#  (5.0, 'Persian Mythology'),
#  (5.0, 'Perfect Dark: Initial Vector'),
#  (5.0, 'Paul Celan: Poet, Survivor, Jew'),
#  (5.0, 'Paul Celan: Poems'),
#  (5.0, 'Parallel Lives'),
#  (5.0, 'Pacto de sangre'),
#  (5.0, 'Owls Well That Ends Well (Meg Langslow, #6)'),
#  (5.0, 'Out of the Woods: Stories'),
#  (5.0, 'Out of the Dark'),
#  (5.0,
#   'Oscar Wilde at Oxford: A Lecture Delivered at the Library of Congress on March 1, 1983'),
#  (5.0, 'Orpheus and Greek Religion: A Study of the Orphic Movement'),
#  (5.0, 'One-Minute Biographies and Art Activities: Grades 2-6'),
#  (5.0, 'One Thousand and One Nights, Volume 03'),
#  (5.0, 'On the Blue Shore of Silence: Poems of the Sea'),
#  (5.0, 'On the Beach'),
#  (5.0, 'Old Soldiers Never Die: The Life of Douglas MacArthur'),
#  (5.0, 'Obayd Zakani: Collected Works'),
#  (5.0, 'O Gattopardo'),
#  (5.0, 'Notes on the Cinematographer'),
#  (5.0, 'Notes On Cinematography'),
#  (5.0, 'Notebooks for an Ethics'),
#  (5.0, 'Normance'),
#  (5.0, 'Nixon Agonistes: The Crisis of the Self-Made Man'),
#  (5.0,
#   'New York Post Sudoku 1: The Official Utterly Addictive Number-Placing Puzzle'),
#  (5.0, 'New Directions in American Intellectual History'),
#  (5.0, "Never Give In!: The Best of Winston Churchill's Speeches"),
#  (5.0, 'Never Give In!'),
#  (5.0,
#   'Nazism 1919-1945, Volume 1: The Rise to Power 1919-1934: A Documentary Reader (Exeter Studies in History) '),
#  (5.0, 'National Electrical Code 2005 Tabs (for Softcover)'),
#  (5.0, 'National Electrical Code 2005'),
#  (5.0, 'Nahj Al-Balaghah (Peak of Eloquence) for Children'),
#  (5.0, "Nabokov's ADA: The Place of Consciousness"),
#  (5.0, 'My Uncle Napoleon'),
#  (5.0, 'Mr. Hitchcock, Wie Haben Sie Das Gemacht?'),
#  (5.0, 'Mother'),
#  (5.0,
#   'Modern Welfare States: Scandinavian Politics and Policy in the Global Age'),
#  (5.0,
#   'Modern Quantum Chemistry: Introduction to Advanced Electronic Structure Theory'),
#  (5.0, 'Mockingbird'),
#  (5.0, 'Mind-Stretching Thinking Activities: Grades 1-6'),
#  (5.0, 'Mind Into Matter: A New Alchemy of Science and Spirit'),
#  (5.0, 'Millennium Art'),
#  (5.0,
#   'Metamorphosis of a Death Symbol: The Transi Tomb in the Late Middle Ages and the Renaissance'),
#  (5.0, 'Memory, History, Forgetting'),
#  (5.0, 'Memorias de Africa'),
#  (5.0, 'Mein Onkel Napoleon'),
#  (5.0, 'Measure of Emptiness: Grain Elevators in the American Landscape'),
#  (5.0,
#   "Mathnawi Of Jalalu'ddin Rumi: Critical Notes (Mathnawi Of Jalalu'ddin Rimi)"),
#  (5.0, 'Mathnawi Mawlana Jalal al-Din al-Rumi'),
#  (5.0, 'Masnavi Mawlana Rumi (Two Volume Set)'),
#  (5.0,
#   "Masnavi I Ma'navi: The Spiritual Couplets of Maulana Jalalu-'D'din Muhammad Rumi"),
#  (5.0, 'Mary Queen of Scots and the Murder of Lord Darnley'),
#  (5.0, 'Mara and Dann'),
#  (5.0, 'Mallorys Orakel (Kathleen Mallory, #1)'),
#  (5.0, "Mallory's Oracle (Kathleen Mallory, #1)"),
#  (5.0, 'Maleficio'),
#  (5.0,
#   'Mage: The Ascension: Pride, Power, Paradox: A Storytelling Game of Reality on the Brink'),
#  (5.0,
#   "Lyndon Johnson's War: America's Cold War Crusade in Vietnam, 1945-1968 (Hill and Wang Critical Issues)"),
#  (5.0, 'Lucky Day'),
#  (5.0, 'Love Poems and Sonnets'),
#  (5.0, 'Lost Illusions (Modern Library)'),
#  (5.0, 'Lost Illusions'),
#  (5.0, 'Los Versos del Capitan'),
#  (5.0, 'Lives of the Noble Greeks and Romans, 2 Vols'),
#  (5.0, 'Lives of the Noble Grecians and Romans'),
#  (5.0, 'Little Black Fish'),
#  (5.0, 'Lincoln (Narratives of a Golden Age)'),
#  (5.0, 'Lincoln'),
#  (5.0, 'Life Support'),
#  (5.0, 'Life & Teaching of the Masters of the Far East'),
#  (5.0, 'Letty Fox: Her Luck'),
#  (5.0, 'Les Heures'),
#  (5.0, 'Les Confessions'),
#  (5.0, 'Les Cigares du Pharaon (Tintin, #4)'),
#  (5.0,
#   'Legalines: Civil Procedure : Adaptable to Eight Edition of Hazard Casebook'),
#  (5.0, 'Leaves from a Grass House'),
#  (5.0, 'Le joueur'),
#  (5.0, 'Le Joueur'),
#  (5.0, 'Layla and Majnun'),
#  (5.0, 'Las horas'),
#  (5.0, 'Las Horas'),
#  (5.0, 'La madre'),
#  (5.0, 'La estrella misteriosa'),
#  (5.0, 'La Niche De La Honte'),
#  (5.0, 'La Marcha Redetzky'),
#  (5.0, 'La Iliada & La Odisea'),
#  (5.0, 'La Hija de Rumi'),
#  (5.0, 'La Chica Del Tambor'),
#  (5.0, 'La Agonia y El Extasis'),
#  (5.0, 'LEGO Game Books: Spy Catcher (Road Maze Game Books, LEGO)'),
#  (5.0, 'Korean Workers: The Culture and Politics of Class Formation'),
#  (5.0, 'Kohle An Bord (Tim und Struppi. #18)'),
#  (5.0, 'Kite Flier'),
#  (5.0, 'Kierkegaard, Religion and the Nineteenth-Century Crisis of Culture'),
#  (5.0, 'Khrushchev Remembers'),
#  (5.0, 'Keys to Drawing'),
#  (5.0, 'Kalidar'),
#  (5.0, 'Julian'),
#  (5.0, 'Journals of Ralph Waldo Emerson, 1820-1824'),
#  (5.0,
#   "Jefferson's Pillow: The Founding Fathers and the Dilemma of Black Patriotism"),
#  (5.0, 'Jean Christophe: in Paris: The Market-Place, Antoinette, The House'),
#  (5.0, "Jean Christophe Journey's End"),
#  (5.0, "James Clavell's Tai-Pan."),
#  (5.0, 'India: Emerging Power'),
#  (5.0, 'In the Heart of the Sea: The Tragedy of the Whaleship Essex'),
#  (5.0, 'In the Heart of the Sea: The Epic True Story That Inspired Moby-Dick'),
#  (5.0, 'In Pale Battalions'),
#  (5.0,
#   'In Flanders Fields and Other Poems About War: Historical Poetry Packaged for Schools'),
#  (5.0, 'In Flanders Fields And Other Poems About War'),
#  (5.0,
#   'In Cold Blood: A True Account of a Multiple Murder and Its Consequences'),
#  (5.0, 'In Cold Blood  '),
#  (5.0, 'In Cold Blood'),
#  (5.0, 'Iliad and Odyssey'),
#  (5.0, 'Il Gattopardo'),
#  (5.0, "I'll Never Be Young Again"),
#  (5.0, 'I Wish That I Had Duck Feet'),
#  (5.0,
#   'I Rode With Jeb Stuart the Life and Campaigns of Maj (Indiana University Civil War Centennial Series)'),
#  (5.0, 'I Heard God Laughing: Renderings of Hafiz'),
#  (5.0, 'I Heard God Laughing: Poems of Hope and Joy'),
#  (5.0, 'Hud'),
#  (5.0, 'How the Catholic Church Built Western Civilization'),
#  (5.0, 'How Many Hearts (Razzle Dazzle Books)'),
#  (5.0, 'House of Sand and Fog '),
#  (5.0, 'House of Sand and Fog'),
#  (5.0, 'Horseman, Pass By '),
#  (5.0, 'Homosexuality: The Secret a Child Dare Not Tell'),
#  (5.0,
#   'Homeric Moments: Clues to Delight in Reading the Odyssey and the Iliad'),
#  (5.0, 'Holy Bible: The Greek New Testament'),
#  (5.0,
#   'Holy Bible: Nestle-aland Novum Testamentum Graece With Greek-English Dictionary'),
#  (5.0, 'Holy Bible: Nestle-aland Novum Testamentum Graece'),
#  (5.0, 'Hitchcock Truffaut (Cine)'),
#  (5.0, 'Hitchcock'),
#  (5.0, 'Herr der Diebe'),
#  (5.0, 'Helter Skelter: The True Story of the Manson Murders'),
#  (5.0, 'Hegel: A Very Short Introduction'),
#  (5.0, 'Harvest Home'),
#  (5.0, 'Harvest'),
#  (5.0, 'Hafiz: The Mystic Poets'),
#  (5.0, 'Hafiz and the Divan'),
#  (5.0, 'Hafiz English-Persian'),
#  (5.0, 'Hafez in Persian & English Pocket Edition'),
#  (5.0, 'Hadis-i biqarari-yi Mahan'),
#  (5.0, 'Guilty'),
#  (5.0, 'Greek-English New Testament (Nestle-Aland, RSV)'),
#  (5.0, 'Greek and Roman Lives'),
#  (5.0, 'Great Short Works: Poems, Tales, Criticism'),
#  (5.0, 'Great Short Works'),
#  (5.0, 'Granta 81: Best of Young British Novelists 2003'),
#  (5.0, "Gould's Book of Fish: A Novel in 12 Fish"),
#  (5.0, "Gould's Book of Fish"),
#  (5.0, "Gould's Book Of Fish A Novel In Twelve Fish"),
#  (5.0,
#   'Gone With the Wind: the definitive illustrated history of the book, the movie, and the legend'),
#  (5.0, 'Golestan: Bilingual English And Persian'),
#  (5.0, 'Going After Cacciato'),
#  (5.0, 'Glasgow: Portraits Of A City'),
#  (5.0, "Giovanni's Room"),
#  (5.0,
#   'Ghost Wars: The Secret History of the CIA, Afghanistan, and bin Laden from the Soviet Invasion to September 10, 2001'),
#  (5.0,
#   'Ghost Wars: The Secret History of the CIA, Afghanistan, and Bin Laden, from the Soviet Invasion to September 10, 2001'),
#  (5.0, 'Gary Carter, the Kid'),
#  (5.0, 'Gary Carter Kid'),
#  (5.0,
#   "Fyodor Dostoyevsky's Crime and Punishment: A Casebook (Casebooks in Criticism)"),
#  (5.0, 'Fuzzy Thinking: The New Science Of Fuzzy Logic'),
#  (5.0, 'Fuzzy Thinking'),
#  (5.0, 'Frog and Toad Are Friends Book and Tape (I Can Read Book 2)'),
#  (5.0, 'Fragments (African Writers Series)'),
#  (5.0, 'Force Continuum'),
#  (5.0, 'Flaubert, Joyce and Beckett: The Stoic Comedians (Lannan Selection)'),
#  (5.0,
#   'Fix-It and Forget-It Lightly: Healthy, Low-Fat Recipes for Your Slow Cooker'),
#  (5.0, 'Fifty Stories'),
#  (5.0, 'Fifty Poems of Hafiz'),
#  (5.0, 'Female Brando: The Legend of Kim Stanley'),
#  (5.0, 'Fear of the Dark (Fearless Jones, #3)'),
#  (5.0, 'Fan Man'),
#  (5.0, 'Fahrenheit 451  '),
#  (5.0, 'Fahrenheit 451 '),
#  (5.0, 'Fahrenheit 451'),
#  (5.0, 'Face-Off! (Girl Talk, #2)'),
#  (5.0, 'Fabulous Small Jews'),
#  (5.0, 'Excel 2007 VBA Programming for Dummies'),
#  (5.0,
#   'Euphues: the Anatomy of Wit and Euphues and His England: An Annotated, Modern-Spelling Edition'),
#  (5.0, 'Encyclopedia Iranica'),
#  (5.0,
#   'Encyclopaedia Iranica: V. 3 Fascicle 3 AZERBAIJAN IV - BACCA(-YE) SAQQA'),
#  (5.0,
#   'Encyclopaedia Iranica, Volume 12: Harem 1 - Illuminationism (Encyclopaedia Iranica, Volume 12)'),
#  (5.0,
#   'Encyclopaedia Iranica, Volume 11: Gioni - Harem I (Encyclopaedia Iranica, Volume 11)'),
#  (5.0,
#   'Encyclopaedia Iranica, Volume 08: Ebn Ayyas-E Tezad-Al-Saltana (Encyclopaedia Iranica, Volume 08)'),
#  (5.0, 'El jugador'),
#  (5.0,
#   'El Senor Presidente: Edicion Critica (Edicion Critica De Las Obras Completas De Miguel Angel Asturias ; 3) (Spanish Edition)'),
#  (5.0, 'El Senor Presidente'),
#  (5.0, 'El Jugador/ The Gambler'),
#  (5.0, 'El Jugador'),
#  (5.0, 'El Gatopardo'),
#  (5.0, 'El Cielo Protector'),
#  (5.0,
#   'Economic Botany: Plants in Our World Economic Botany: Plants in Our World'),
#  (5.0, 'Echoes in the Wind (Summerhill Secrets, #7)'),
#  (5.0, 'East Lynne'),
#  (5.0, "Du plus loin de l'oubli"),
#  (5.0,
#   'Dreamworld and Catastrophe: The Passing of Mass Utopia in East and West'),
#  (5.0, 'Dr. Jekyll and Mr. Hyde: A Kaplan SAT Score-Raising Classic'),
#  (5.0, 'Dr. Jekyll and Mr. Hyde'),
#  (5.0, 'Dr. Jekyll & Mr. Hyde & The Turn Of The Screw'),
#  (5.0, 'Dr Jekyll and Mr Hyde'),
#  (5.0, 'Double Indemnity'),
#  (5.0, 'Double Down: Reflections on Gambling and Loss'),
#  (5.0,
#   'Dodge Caravan, Plymouth Voyager & Chrysler Town & Country Automotive Repair Manual'),
#  (5.0, 'Divan of Hafez Persian-English'),
#  (5.0, 'Dispatches'),
#  (5.0, 'Dime Uno Cuaderno De Actividades'),
#  (5.0,
#   'Did I Ever Tell You How Lucky You Are?: Yellow Back Book (Dr. Seuss - Yellow Back Book)'),
#  (5.0, 'Did I Ever Tell You How Lucky You Are?'),
#  (5.0, 'Desire Lines'),
#  (5.0, "Desert Night Shift: A Pack Rat's Story [With Stuffed Animal]"),
#  (5.0, 'Der Spieler. Aus den Aufzeichnungen eines jungen Mannes.'),
#  (5.0, 'Der Spieler'),
#  (5.0, 'Der Leopard'),
#  (5.0, 'Death Without Company (Walt Longmire, #2)'),
#  (5.0, 'Dearly Depotted (A Flower Shop Mystery, #3)'),
#  (5.0, "Dead Man's Island (Henrie O, #1)"),
#  (5.0, 'Dead City'),
#  (5.0,
#   "David and Solomon: In Search of the Bible's Sacred Kings and the Roots of the Western Tradition"),
#  (5.0, 'Darkness at Noon'),
#  (5.0,
#   'Dar Astin-E Morraqa (Under the Cloak of Hypocrisy) (Persian Language Publications Series , No 8)'),
#  (5.0, 'Cupboards of Curiosity: Women, Recollection, and Film History'),
#  (5.0, 'Culture & Truth: The Remaking of Social Analysis'),
#  (5.0, 'Crime and Punishment: A Mind to Murder'),
#  (5.0, 'Crash'),
#  (5.0, 'Cracking the AP Chemistry Exam'),
#  (5.0,
#   'Covenant of Peace: The Missing Peace in New Testament Theology and Ethics'),
#  (5.0, 'Country Music, U.S.A.'),
#  (5.0, 'Counting Sheep: Twenty Ways of Seeing Desert Bighorn'),
#  (5.0, 'Corazon Tan Blanco'),
#  (5.0, 'Cooperative Learning: Across the Curriculum, Grades K-6'),
#  (5.0,
#   'Conversations with the Dead: Photos. of Prison Life, with the Letters and Drawings of Billy McCune #122054'),
#  (5.0, 'Confessions of Jean-Jacques Rousseau'),
#  (5.0, 'Confessions'),
#  (5.0, 'Complete Works (Picador Classics)'),
#  (5.0, 'Clanbook: Malkavian Revised'),
#  (5.0, 'Clanbook: Assamite Revised'),
#  (5.0, 'Ciudad de huesos (Harry Bosch, #8)'),
#  (5.0, 'City of Bones (Harry Bosch, #8; Harry Bosch Universe, #10)'),
#  (5.0, 'City Of Bones'),
#  (5.0, 'Citizen Vince'),
#  (5.0, 'Cinderella (Reusable Sticker Book)'),
#  (5.0, 'Cigars of the Pharaoh (Tintin #4)'),
#  (5.0, 'Church Dogmatics 5 Index with Aids to the Preacher'),
#  (5.0, 'Church Dogmatics 5 Index with Aids for the Preacher'),
#  (5.0, 'Church Dogmatics 5'),
#  (5.0, 'Christina Stead: A Biography'),
#  (5.0, 'Chosrou und Schirin'),
#  (5.0, 'Childhood Is Hell'),
#  (5.0, 'Child of God'),
#  (5.0, 'Chemistry: A Guided Inquiry'),
#  (5.0, 'Charles Bukowski'),
#  (5.0, 'Catch a Falling Star (Summerhill Secrets, #3)'),
#  (5.0, 'Casa de Arena y Niebla'),
#  (5.0, 'Capitalism and Material Life, 1400-1800'),
#  (5.0, 'Capitalism & Material Life, 1400-1800'),
#  (5.0, 'Cantes Flamencos'),
#  (5.0, 'Canon of Medicine'),
#  (5.0, 'Camp Girl-Meets-Boy'),
#  (5.0, 'Calligraphy and Islamic Culture'),
#  (5.0, 'Burr'),
#  (5.0,
#   "Bryson City Tales: Stories of a Doctor's First Year of Practice in the Smoky Mountains"),
#  (5.0, 'Book Club: A Literature-Based Curriculum (2nd Edition)'),
#  (5.0, 'Bombay Time'),
#  (5.0, 'Bob Dylan - The 6 Chord Songbook'),
#  (5.0, 'Blue Smoke (Tamar Deane Trilogy #3)'),
#  (5.0, 'Bloody Passage'),
#  (5.0, 'Blood on the Moon: The Assassination of Abraham Lincoln'),
#  (5.0, 'Blockade Diary'),
#  (5.0, 'Black Little Fish'),
#  (5.0, 'Beyond the Barriers: The Book of Worlds'),
#  (5.0, "Bataille's Eye: And ICI Field Notes 4"),
#  (5.0, 'Bartleby e Companhia'),
#  (5.0, 'Bartleby & Co.'),
#  (5.0, 'Ball Four: The Final Pitch'),
#  (5.0,
#   'Ball Four: My Life and Hard Times Throwing the Knuckleball in the Big Leagues'),
#  (5.0, 'Ball Four Plus Ball Five: An Update, 1970-1980'),
#  (5.0, 'Ball Four Plus Ball Five'),
#  (5.0, 'Ball Four'),
#  (5.0, 'Back to the Sources'),
#  (5.0, 'Babylon'),
#  (5.0, 'Assurance sur la mort'),
#  (5.0, 'Asphodel'),
#  (5.0, 'Antigone / Oedipus the King / Electra'),
#  (5.0, 'Anna Karenina, 1'),
#  (5.0, 'Andrei Rublev'),
#  (5.0, 'An Instance of the Fingerpost'),
#  (5.0, 'An Instance Of The Fingerpost'),
#  (5.0, 'American Sphinx: The Character of Thomas Jefferson'),
#  (5.0, 'American Caesar: Douglas MacArthur, 1880-1964'),
#  (5.0, 'American Caesar: Douglas MacArthur 1880-1964'),
#  (5.0, 'Amazing Rain'),
#  (5.0, 'All the Love Poems of Shakespeare'),
#  (5.0, "All the King's Men"),
#  (5.0, 'All about H. Hatterr'),
#  (5.0, "All The King's Men"),
#  (5.0, 'All Souls'),
#  (5.0,
#   "All Day Permanent Red: The First Battle Scenes of Homer's Iliad Rewritten"),
#  (5.0,
#   "All Day Permanent Red: An Account of the First Battle Scenes of Homer's Iliad"),
#  (5.0, 'Agatha Raisin and the Walkers of Dembley (Agatha Raisin, #4)'),
#  (5.0, 'Aesops Fables'),
#  (5.0, 'Aesop: The Complete Fables'),
#  (5.0, "Aesop's Fables Coloring Book"),
#  (5.0, "Aesop's Fables "),
#  (5.0, "Aesop's Fables"),
#  (5.0,
#   'Adventuring With Books: A Booklist for Pre-K - Grade 6 1997 (Ncte Bibliography Series, 1051-4740)'),
#  (5.0, 'Acts of Violets (A Flower Shop Mystery, #5)'),
#  (5.0, 'Absalon, Absalon !'),
#  (5.0, 'Absalom, Absalom! : The Corrected Text'),
#  (5.0, 'Absalom, Absalom!'),
#  (5.0,
#   'A Splendor of Letters: The Permanence of Books in an Impermanent World'),
#  (5.0, 'A Single Man'),
#  (5.0, 'A Separate Peace with related Readings'),
#  (5.0, 'A Separate Peace with Connections (HRW Library)'),
#  (5.0, 'A Separate Peace'),
#  (5.0, 'A Preface to Paradise Lost: Ballard Matthews Lecture 1941'),
#  (5.0, 'A Preface to Paradise Lost'),
#  (5.0, 'A Persian Requiem'),
#  (5.0,
#   'A Natural History of Pragmatism: The Fact of Feeling from Jonathan Edwards to Gertrude Stein'),
#  (5.0, 'A Month of Sundays'),
#  (5.0, 'A Month in the Country'),
#  (5.0, 'A Long and Happy Life'),
#  (5.0, 'A History of the World in 10 1/2 Chapters'),
#  (5.0, 'A History of Greek Philosophy 6: Aristotle: An Encounter'),
#  (5.0, 'A History of Greek Philosophy 5: Later Plato & the Academy'),
#  (5.0,
#   'A History of Greek Philosophy 4: Plato: The Man & His Dialogues: Earlier Period'),
#  (5.0, 'A History of Greek Philosophy 3: The Fifth-Century Enlightenment'),
#  (5.0,
#   'A History of Greek Philosophy 3: The Fifth Century Enlightenment, Part 2, Socrates'),
#  (5.0,
#   'A History of Greek Philosophy 3: The Fifth Century Enlightenment, Part 1, The Sophists'),
#  (5.0,
#   'A History of Greek Philosophy 2: The Presocratic Tradition from Parmenides to Democritus'),
#  (5.0, 'A History of Greek Philosophy 1'),
#  (5.0, 'A History of Ancient Israel and Judah'),
#  (5.0, 'A Heart So White'),
#  (5.0, 'A Handful of Dust'),
#  (5.0, 'A Godward Life: Savoring the Supremacy of God in All of Life'),
#  (5.0, 'A Godward Life'),
#  (5.0, 'A Garden Beyond Paradise'),
#  (5.0, 'A Frolic of His Own'),
#  (5.0, 'A Estrela Misteriosa: As Aventuras de Tintin'),
#  (5.0, 'A Confederate General from Big Sur'),
#  (5.0, 'A Companion to Greek Tragedy'),
#  (5.0,
#   'A Change of Hearts: Plays, Films, and Other Dramatic Works, 1951-1971'),
#  (5.0,
#   'A Bargain for Frances (Spanish edition): El gran negocio de Francisca'),
#  (4.0, 'state and revolution'),
#  (4.0, 'guardians'),
#  (4.0, 'Yonqui'),
#  (4.0, 'Yerma'),
#  (4.0, 'Year of Wonders'),
#  (4.0, 'Word and Image'),
#  (4.0,
#   "Women Who Love Too Much: When You Keep Wishing and Hoping He'll Change"),
#  (4.0, 'Women Who Love Too Much'),
#  (4.0, 'Wolfgang Tillmans'),
#  (4.0, 'Without a Trace (Rock Harbor Series #1)'),
#  (4.0,
#   "With God on Our Side: One Man's War Against an Evangelical Coup in America's Military"),
#  (4.0, 'Winter in the Blood'),
#  (4.0, 'Winter Garden'),
#  (4.0, 'Wings of Fire (Inspector Ian Rutledge, #2)'),
#  (4.0, 'Will in the World: How Shakespeare Became Shakespeare '),
#  (4.0, 'Will in the World: How Shakespeare Became Shakespeare'),
#  (4.0,
#   "Why the Lyrical Ballads?: The Background, Writing, and Character of Wordsworth's 1798 Lyrical Ballads"),
#  (4.0,
#   "Who Says Elephants Can't Dance?: Leading a Great Enterprise through Dramatic Change"),
#  (4.0, "Who Says Elephants Can't Dance?"),
#  (4.0, "Where's That Monkey?"),
#  (4.0, 'When the Elephants Came'),
#  (4.0, 'When We Were Gods: A Novel of Cleopatra'),
#  (4.0, 'When Schools Compete: A Cautionary Tale'),
#  (4.0, 'When Patty Went to College'),
#  (4.0, "When Being Good Isn't Good Enough"),
#  (4.0,
#   'What Did the Biblical Writers Know and When Did They Know It? What Archeology Can Tell Us about the Reality of Ancient Israel'),
#  (4.0, 'Welcome to Hard Times'),
#  (4.0,
#   "Wedding in Paris: We'll Always Have Paris/Something Borrowed, Something Blue/Picture Perfect"),
#  (4.0, 'Wedding Day Murder (A Lucy Stone Mystery, #8)'),
#  (4.0, 'Way of the Magus'),
#  (4.0, "Washington's Spies: The Story of America's First Spy Ring"),
#  (4.0, 'Warhammer Fantasy Roleplay Realms of Sorcery'),
#  (4.0, 'Vuelo 714 para Sidney'),
#  (4.0, 'Voyage of the Jaffa Wind (The Secrets of Droon, #14)'),
#  (4.0, 'Volando solo'),
#  (4.0, 'Vivir Depues De La Perdida'),
#  (4.0, 'Viva Cuba Libre !'),
#  (4.0, 'Virgin Soil Upturned: Book One'),
#  (4.0, 'Virgin Soil Upturned, Book 2'),
#  (4.0, 'Virgin Soil Upturned, Book 1 (Volume 1)'),
#  (4.0, 'Virgin Soil Upturned, Book 1'),
#  (4.0, 'Virgin Soil Upturned'),
#  (4.0, 'Virgil'),
#  (4.0, 'Vino E Pane'),
#  (4.0, 'Vicomte Pourfendu (Le)'),
#  (4.0, 'Vendedor de cuentos'),
#  (4.0, 'Variations Enigmatiques'),
#  (4.0, 'Vanished!'),
#  (4.0, 'Van Gogh'),
#  (4.0, "Usher's Passing"),
#  (4.0,
#   'Understanding China and India: Security Implications for the United States and the World'),
#  (4.0, 'Under the Lilacs'),
#  (4.0, 'Under Western Eyes '),
#  (4.0, 'Under Western Eyes'),
#  (4.0, 'Un barrage contre le Pacifique'),
#  (4.0, 'Un ami de la terre'),
#  (4.0, 'Un Capitan De Quince Anos'),
#  (4.0, 'Ulysses on the Liffey'),
#  (4.0, 'Ultimate Sheet Metal Fabrication Book'),
#  (4.0,
#   'Two Towers: The De Christianization Of America And A Plan For Renewal'),
#  (4.0, 'Twenty-Three Tales'),
#  (4.0, 'Truck Company Operations'),
#  (4.0,
#   'Trout Fishing in America / The Pill vs. the Springhill Mine Disaster / In Watermelon Sugar'),
#  (4.0, 'Triumph Of Painting'),
#  (4.0,
#   'Triple Cross: Holy Place / Hell Has No Limits / From Cuba with a Song'),
#  (4.0,
#   'Tribute to Freud: Writing on the Wall and Advent (New Directions Paperbook)'),
#  (4.0, 'Tribulaciones de un chino en China'),
#  (4.0, 'Travels with Charley: In Search of America'),
#  (4.0, 'Traumnovelle'),
#  (4.0,
#   'Transactional Analysis in Psychotherapy: A Systematic Individual and Social Psychiatry'),
#  (4.0, 'Transactional Analysis in Psychotherapy'),
#  (4.0, 'Topaz'),
#  (4.0, 'Tomorrow and Tomorrow'),
#  (4.0, 'Tolstoy'),
#  (4.0, 'Tintin: El templo del sol'),
#  (4.0, 'Tintin y el Lago de los Tiburones'),
#  (4.0, 'Tintin in the Land of the Soviets (Tintin, #1)'),
#  (4.0, 'Tintin in the Land of the Soviets (Tintin #1)'),
#  (4.0, 'Tintin in Tibet (Tintin, #20)'),
#  (4.0, 'Tintin et le lac aux requins'),
#  (4.0, "Tintin et l'Alph-Art (Tintin, #24)"),
#  (4.0, "Tintin au pays de l'or noir  (Tintin, #15)"),
#  (4.0, 'Tintin and the Picaros (Tintin, #23)'),
#  (4.0, 'Tintin and the Picaros'),
#  (4.0,
#   'Tintin and the Lake of Sharks (Tintin Film Book) (The Adventures of Tintin)'),
#  (4.0, 'Tintin and the Lake of Sharks'),
#  (4.0, 'Tintin and Alph-Art (Tintin, #24)'),
#  (4.0, 'Time and the Gods'),
#  (4.0, 'Time Was Soft There: A Paris Sojourn at Shakespeare & Co.'),
#  (4.0, 'Tim und der Haifischsee (Tim und Struppi, #23)'),
#  (4.0, 'Tim im Lande der Sowjets (Tintin, #1)'),
#  (4.0, 'Tides of Darkness (World of Warcraft, #3)'),
#  (4.0, 'Three Tragedies: Blood Wedding, Yerma, Bernarda Alba'),
#  (4.0, 'Three Plays: Blood Wedding; Yerma; The House of Bernarda Alba'),
#  (4.0, 'Three Plays: Blood Wedding/Yerma/the House of Bernada Alba'),
#  (4.0, 'Three Act Tragedy'),
#  (4.0, "Thomas Hardy's Return of the Native"),
#  (4.0, 'This Breathing World'),
#  (4.0, 'Third Wave'),
#  (4.0, 'Things Change'),
#  (4.0, 'They Thirst'),
#  (4.0, "There's a Boy in the Girls' Bathroom"),
#  (4.0, "There's A Boy In The Girls' Bathroom"),
#  (4.0, "There's A Boy In The Girl's Bathroom"),
#  (4.0, 'There Is a Boy in the Girls Bathroom'),
#  (4.0, 'Theories of Personality'),
#  (4.0, 'The Zion Chronicles'),
#  (4.0, 'The Young Lions'),
#  (4.0, 'The Yerma - 131 -'),
#  (4.0, 'The Yellow-Lighted Bookshop: A Memoir, a History'),
#  (4.0, 'The Yellow Dog (Maigret #6)'),
#  (4.0,
#   'The Works Of Charles Dickens: Great Expectations, Hard Times, A Christmas Carol, A Tale Of Two Cities'),
#  (4.0, 'The Woman in Black'),
#  (4.0, 'The Wolfen'),
#  (4.0, "The Wild Ass's Skin"),
#  (4.0, 'The White Lioness (Kurt Wallander, #3)'),
#  (4.0,
#   'The Wheel of Time: The Shamans of Mexico Their Thoughts About Life Death & the Universe'),
#  (4.0, 'The Well of Eternity (WarCraft: War of the Ancients, #1)'),
#  (4.0, 'The Way of a Pilgrim: And the Pilgrim Continues His Way'),
#  (4.0, 'The Way of a Pilgrim: And The Pilgrim Continues His Way'),
#  (4.0, 'The Way of a Pilgrim and the Pilgrim Continues His Way'),
#  (4.0, 'The Way of Chuang Tzu (Shambhala Library)'),
#  (4.0, 'The War'),
#  (4.0, 'The Voyages of Doctor Dolittle (Doctor Dolittle, #2)'),
#  (4.0, 'The Voyages of Doctor Dolittle'),
#  (4.0, 'The Unexpected George Washington'),
#  (4.0, 'The Tower of the Elf King (The Secrets of Droon, #9)'),
#  (4.0, 'The Third Wave: The Classic Study of Tomorrow'),
#  (4.0, 'The Third Wave'),
#  (4.0, 'The Thin Man  '),
#  (4.0, 'The Thin Man'),
#  (4.0, 'The Terminal Beach'),
#  (4.0, 'The Tears of Autumn'),
#  (4.0, 'The Sword of the Spirits (The Sword of the Spirits, #3)'),
#  (4.0, 'The Survivor: Bill Clinton in the White House'),
#  (4.0, 'The Survivor: Bill Clinton In The White House'),
#  (4.0, 'The Sunshine Boys'),
#  (4.0, 'The Sundering (WarCraft: War of the Ancients, #3)'),
#  (4.0, 'The Story of the Lords of Wisdom'),
#  (4.0, 'The Story of San Michele'),
#  (4.0, 'The Story of Mr Sommer'),
#  (4.0, 'The Story of Doctor Dolittle (Doctor Dolittle, #1)'),
#  (4.0, 'The Story of Doctor Dolittle'),
#  (4.0, 'The Story Of Mr. Sommer'),
#  (4.0, 'The Stepford Wives (Lernmaterialien)'),
#  (4.0, 'The Stepford Wives'),
#  (4.0, 'The State and Revolution'),
#  (4.0, 'The State And Revolution'),
#  (4.0, 'The Song of the Last Miguel'),
#  (4.0, 'The Song of Songs: A New Translation'),
#  (4.0, 'The Song of Solomon (Pocket Canons, #6)'),
#  (4.0, 'The Smile at the Foot of the Ladder'),
#  (4.0, 'The Sisters (The Ordeal, #1)'),
#  (4.0, 'The Shawshank Redemption: The Shooting Script'),
#  (4.0, 'The Seven Wonders of the Ancient World'),
#  (4.0, 'The Seven Crystal Balls (Tintin, #13)'),
#  (4.0, 'The Sentinel '),
#  (4.0, 'The Sentinel'),
#  (4.0,
#   'The Self Possessed: Deity and Spirit Possession in South Asian Literature and Civilization'),
#  (4.0, 'The Secret of the Abiding Presence'),
#  (4.0, 'The Second Ring of Power'),
#  (4.0, 'The Second Omni Book of Science Fiction'),
#  (4.0, "The Science of Discworld III: Darwin's Watch"),
#  (4.0, 'The Savage Kingdom'),
#  (4.0, 'The Sanctuary of the Soul: Selected Writings'),
#  (4.0, 'The Roots of Romanticism'),
#  (4.0, 'The Road to Oxiana (Picador Travel Classics)'),
#  (4.0, 'The Road to Oxiana'),
#  (4.0, 'The Road To Oxiana'),
#  (4.0, "The River of Doubt: Theodore Roosevelt's Darkest Journey"),
#  (4.0, "The Ringmaster's Daughter"),
#  (4.0, 'The Return of the Native  '),
#  (4.0, 'The Return of the Native '),
#  (4.0, 'The Return of the Native'),
#  (4.0, 'The Return of the Dancing Master'),
#  (4.0, 'The Return Of Native'),
#  (4.0, 'The Rainbow of Desire: The Boal Method of Theatre and Therapy'),
#  (4.0, 'The Progressive Party: The Success of a Failed Party'),
#  (4.0, 'The Prince in Waiting (The Sword of the Spirits, #1)'),
#  (4.0,
#   'The Present[The Gift That Makes You Happy And Successful At Work And In Life]'),
#  (4.0, 'The Present : The Secret to Enjoying Your Work And Life, Now!'),
#  (4.0, 'The Precious Present (Helen Exley Giftbook)'),
#  (4.0, 'The Precious Present'),
#  (4.0, 'The Power of Silence: Further Lessons of Don Juan'),
#  (4.0, 'The Power Of Silence (Export Ed.)'),
#  (4.0,
#   "The Politics of Literary Reputation: The Making and Claiming of 'St. George' Orwell"),
#  (4.0,
#   'The Political Economy Of Modern Iran: Despotism And Pseudo Modernism, 1926 1979'),
#  (4.0, 'The Poems of Emily Dickinson: Reading Edition'),
#  (4.0, 'The Poems of Emily Dickinson'),
#  (4.0,
#   'The Plane Truth for Golfers Master Class: Advanced Lessons for Improving Swing Technique and Ball Control for the One-Plane and Two-Plane Swings'),
#  (4.0, 'The Places as Preludes'),
#  (4.0, 'The Phantom of the Opera'),
#  (4.0,
#   'The Persian Sphinx: Amir Abbas Hoveyda and the Riddle of the Iranian Revolution'),
#  (4.0, 'The Pelican Brief '),
#  (4.0, 'The Pelican Brief'),
#  (4.0, 'The Patient Stone (Persian Fiction in Translation)'),
#  (4.0, "The Paston Family in the Fifteenth Century: Volume 2, Fastolf's Will"),
#  (4.0,
#   'The Paston Family in the Fifteenth Century: Volume 1, the First Phase'),
#  (4.0, 'The Passions of the Mind'),
#  (4.0, 'The Parsley Garden'),
#  (4.0, 'The Palace of Dreams'),
#  (4.0, 'The Oxford Companion to African American Literature'),
#  (4.0, 'The Oxford Book of Latin American Short Stories'),
#  (4.0, 'The Omen'),
#  (4.0,
#   'The Numerology of the I Ching: A Sourcebook of Symbols, Structures, and Traditional Wisdom'),
#  (4.0, 'The Nuclear Winter Man'),
#  (4.0, 'The Nocturnal Harmony Of Wood Instruments'),
#  (4.0,
#   'The Nine Billion Names of God & Other Stories (The Collected Stories of Arthur C. Clarke #3)'),
#  (4.0, 'The Night in Question'),
#  (4.0, 'The Night In Question'),
#  (4.0,
#   'The New Soviet Psychic Discoveries: A First-Hand Report on the Startling Breakthroughs in Russian Parapsychology'),
#  (4.0,
#   'The New Soviet Psychic Discoveries: A First-Hand Report on the Startling Breakthrough in Russian Parapsychology'),
#  (4.0, 'The New Soviet Psychic Discoveries'),
#  (4.0, 'The Narrow House'),
#  (4.0, 'The Naked Sun (Robot, #2)'),
#  (4.0, 'The Naked Sun (Robot #2)'),
#  (4.0, 'The Myth of the Eternal Return: Cosmos and History '),
#  (4.0, 'The Myth of the Eternal Return or Cosmos and History'),
#  (4.0, 'The Mysterious Island (The Secrets of Droon, #3)'),
#  (4.0, 'The Mousetrap and Selected Plays'),
#  (4.0, 'The Mousetrap and Other Plays '),
#  (4.0, 'The Mousetrap and Other Plays'),
#  (4.0, 'The Mousetrap And Other Plays'),
#  (4.0, 'The Mother'),
#  (4.0, 'The Moon Scroll (The Secrets Of Droon, #15)'),
#  (4.0, 'The Missing Piece Meets the Big O '),
#  (4.0, 'The Mercury Visions of Louis Daguerre'),
#  (4.0, 'The Meaning of Life'),
#  (4.0, 'The Marx Sisters (Brock & Kolla, #1)'),
#  (4.0, 'The Man Who Turned into a Stick: Three Related Plays'),
#  (4.0, 'The Man Who Knew Too Much'),
#  (4.0, 'The Making of Americans'),
#  (4.0, 'The Magic Skin'),
#  (4.0, 'The Lover'),
#  (4.0, 'The Lost Amazon'),
#  (4.0, 'The Lodger: Library Edition'),
#  (4.0, 'The Lodger'),
#  (4.0, 'The Living I Ching: Using Ancient Chinese Wisdom to Shape Your Life'),
#  (4.0, 'The Little Match Girl'),
#  (4.0, 'The Lion King - Trumpet'),
#  (4.0, 'The Last Full Measure (The Civil War Trilogy, #3)'),
#  (4.0, 'The Last Full Measure'),
#  (4.0, 'The Last Days'),
#  (4.0, 'The Last Book of the Universe'),
#  (4.0, 'The Last Book In The Universe'),
#  (4.0, 'The Ipcress File (Secret File, #1)'),
#  (4.0,
#   'The Impact of Franklin Pierce on Nathaniel Hawthorne: Friendship, Politics, and the Literary Imagination'),
#  (4.0, "The Icebound Land (Ranger's Apprentice, #3)"),
#  (4.0,
#   'The Humane Metropolis: People and Nature in the 21st-Century City [With DVD]'),
#  (4.0, 'The Human Comedy'),
#  (4.0, 'The House of Bernarda Alba and Other Plays'),
#  (4.0, 'The Horse King (Dragonrealm, #7)'),
#  (4.0, 'The Honorary Consul'),
#  (4.0, 'The Home and the World'),
#  (4.0,
#   'The Holotropic Mind: The Three Levels of Human Consciousness and How They Shape Our Lives'),
#  (4.0, 'The Holographic Universe'),
#  (4.0, 'The High King (The Chronicles of Prydain #5)'),
#  (4.0, 'The High King (The Chronicles of Prydain # 5)'),
#  (4.0,
#   "The Hidden War: A Russian Journalist's Account of the Soviet War in Afghanistan"),
#  (4.0, 'The Heat of the Day'),
#  (4.0, 'The Hearts of Men: American Dreams and the Flight from Commitment'),
#  (4.0, 'The Hawk Bandits of Tarkoom (The Secrets of Droon, #11)'),
#  (4.0, 'The Hamlet: Nineteen Forty, Preliminary Materials'),
#  (4.0, 'The Guardians'),
#  (4.0, 'The Greek Myths'),
#  (4.0, 'The Great Philosophers: An Introduction to Western Philosophy'),
#  (4.0, 'The Great Fortune (Balkan Trilogy #1)'),
#  (4.0, 'The Grass Crown (Masters of Rome, #2)'),
#  (4.0, 'The Grass Crown (Masters of Rome 2)'),
#  (4.0, 'The Good Conscience'),
#  (4.0, 'The Golden Gizmo'),
#  (4.0, 'The Glass Lake'),
#  (4.0, 'The Girl with a Pearl Earring'),
#  (4.0, 'The Gardener'),
#  (4.0, 'The Garden Next Door'),
#  (4.0, 'The Gadfly'),
#  (4.0, 'The Fortress of the Treasure Queen (The Secrets of Droon, #23)'),
#  (4.0,
#   'The Forgotten Language: An Introduction to the Understanding of Dreams, Fairy Tales, and Myths'),
#  (4.0, 'The Flowers of Hiroshima'),
#  (4.0, 'The Flowers of Evil & Paris Spleen'),
#  (4.0,
#   'The First-Aid Companion for Dogs and Cats: What to Do Now, What to Do Later, over 150 Everyday Accidents and Emergencies, Essential Medicine Chest, At-A-Glance Symptom Finder, How to Prevent'),
#  (4.0, 'The First Aid Companion for Dogs & Cats (Prevention Pets)'),
#  (4.0,
#   'The Fifth Discipline: The Art and Practice of the Learning Organization'),
#  (4.0,
#   'The Fifth Discipline: The Art & Practice of the Learning Organization'),
#  (4.0,
#   'The Fifth Discipline: The Art & Practice of The Learning Organization'),
#  (4.0, 'The Fairy Tales of Hermann Hesse'),
#  (4.0,
#   "The Facilitator's Book of Questions: Tools for Looking Together at Student and Teacher Work"),
#  (4.0, 'The Eye of the Prophet'),
#  (4.0, 'The Extraordinary Adventures of Arsne Lupin, Gentleman-Burglar'),
#  (4.0, 'The Extraordinary Adventures of Arsene Lupin, Gentleman-Burglar'),
#  (4.0, 'The Extraordinary Adventures of Arsene Lupin Gentleman-Burglar'),
#  (4.0, 'The Exploits of Arsene Lupin'),
#  (4.0, 'The Exorcist'),
#  (4.0, 'The Eternity Code (Artemis Fowl, Book 3)'),
#  (4.0, 'The Eternity Code (Artemis Fowl, #3)'),
#  (4.0,
#   "The Essential Akutagawa: Rashomon, Hell Screen, Cogwheels, a Fool's Life and Other Short Fiction"),
#  (4.0, 'The Egyptian'),
#  (4.0, 'The Eagle Has Landed (Liam Devlin, #1)'),
#  (4.0, 'The Dragon Crown (Dragonrealm, #6)'),
#  (4.0,
#   'The Devil in the Kitchen: Sex, Pain, Madness and the Making of a Great Chef'),
#  (4.0, 'The Devil'),
#  (4.0, "The Design of Rimbaud's Poetry"),
#  (4.0, 'The Demon Soul (WarCraft: War of the Ancients, #2)'),
#  (4.0, 'The Decline and Fall of the American Empire'),
#  (4.0, 'The Deadly Percheron'),
#  (4.0, 'The Day of the Jackal'),
#  (4.0, 'The Day Of The Jackal'),
#  (4.0, 'The Dark Half'),
#  (4.0, 'The Cuban Missile Crisis'),
#  (4.0, "The Crash of '79"),
#  (4.0, 'The Counterfeiters'),
#  (4.0, 'The Complete Works'),
#  (4.0,
#   "The Complete Plays: The Hostage / The Quare Fellow / Richard's Cork Leg / Moving Out / A Garden Party / The Big House"),
#  (4.0, 'The Complete English Poems'),
#  (4.0, 'The Clouded Leopard: Travels To Landscapes Of Spirit And Desire'),
#  (4.0, 'The City and the House'),
#  (4.0,
#   'The Christian Salt & Light Company: A Contemporary Study of the Sermon on the Mount'),
#  (4.0, 'The Chariot of Queen Zara (The Secrets of Droon, #27)'),
#  (4.0, 'The Changing Light at Sandover'),
#  (4.0, 'The Chakra Handbook'),
#  (4.0, 'The Centaur'),
#  (4.0, 'The Casualty'),
#  (4.0, 'The Castle of Llyr (The Chronicles of Prydain #3)'),
#  (4.0, 'The Call of the Toad'),
#  (4.0, 'The Broker (Audio CD)'),
#  (4.0, 'The Broker'),
#  (4.0, 'The Bride Wore Black'),
#  (4.0, 'The Breaking Point'),
#  (4.0, 'The Bormann Testament (Paul Chavasse #1)'),
#  (4.0, 'The Book of the Secrets of Enoch'),
#  (4.0, "The Book of Coffee: A Gourmet's Guide"),
#  (4.0, 'The Black Tulip'),
#  (4.0, 'The Black Cauldron (The Chronicles of Prydain #2)'),
#  (4.0, 'The Best of Isaac Asimov Unabridged ( Audio Cassette )'),
#  (4.0, 'The Best of Isaac Asimov'),
#  (4.0, 'The Best of Annals of Improbable Research'),
#  (4.0, 'The Best American Magazine Writing 2002'),
#  (4.0,
#   "The Belgariad Boxed Set: Pawn of Prophecy / Queen of Sorcery / Magician's Gambit / Castle of Wizardry / Enchanters' End Game (The Belgariad, #1-5)"),
#  (4.0, 'The Beatles Off the Record: The Dream Is Over'),
#  (4.0, "The Battle for Skandia (Ranger's Apprentice, #4)"),
#  (4.0, 'The Bataille Reader'),
#  (4.0, 'The Assistant'),
#  (4.0, "The Art of the Ridiculous Sublime: On David Lynch's Lost Highway"),
#  (4.0, 'The Art of Dreaming'),
#  (4.0, 'The Arctic Incident (Artemis Fowl, #2)'),
#  (4.0, 'The Antichrist'),
#  (4.0, 'The Anti-Christ'),
#  (4.0,
#   "The Animals' Lawsuit Against Humanity: An Illustrated 10th Century Iraqi Ecological Fable"),
#  (4.0,
#   'The Age of Spiritual Machines: When Computers Exceed Human Intelligence '),
#  (4.0, 'The Age of Louis XIV (The Story of Civilization, #8)'),
#  (4.0, 'The Adventures of Tintin: Land of Black Gold'),
#  (4.0, 'The Adventures of Hajji Baba of Ispahan'),
#  (4.0, 'The Adventures of Captain Hatteras (Extraordinary Voyages, #2)'),
#  (4.0, 'The Abortion'),
#  (4.0, 'Thailand Fever'),
#  (4.0, 'Texts For Nothing'),
#  (4.0, 'Terror Stalks the Class Reunion'),
#  (4.0, 'Terra: Cooking from the Heart of Napa Valley'),
#  (4.0, 'Tensegrity. Die Magischen Bewegungen Der Zauberer'),
#  (4.0, "Ten Days' Wonder (Ellery Queen Detective, #19)"),
#  (4.0, 'Taxi Driver'),
#  (4.0, 'Tartuffe'),
#  (4.0, 'Taran Wanderer (The Chronicles of Prydain #4)'),
#  (4.0, 'Taliban'),
#  (4.0, 'Tales of the Greek Heroes: Retold From the Ancient Authors'),
#  (4.0, 'Tales of the Black Widowers (The Black Widowers, #1)'),
#  (4.0, 'Tales of the Black Widowers'),
#  (4.0,
#   "Tales of a Shaman's Apprentice: An Ethnobotanist Searches for New Medicines in the Amazon Rain Forest"),
#  (4.0,
#   'Take a Nap! Change Your Life.: The Scientific Plan to Make You Smarter, Healthier, More Productive'),
#  (4.0, 'Symphonie der Toten'),
#  (4.0, 'Sweet Land Stories'),
#  (4.0, 'Super Manolito'),
#  (4.0, "Summer of '49 "),
#  (4.0, "Summer of '49"),
#  (4.0, 'Suddenly Sixty And Other Shocks Of Later Life'),
#  (4.0, 'Suddenly Last Summer'),
#  (4.0, 'Stray Birds'),
#  (4.0, 'Strangled Prose (Claire Malloy, #1)'),
#  (4.0, 'Strange Pilgrims'),
#  (4.0, 'Story Of Mr Sommer'),
#  (4.0, 'Stories and Texts for Nothing'),
#  (4.0, 'Stink and the Incredible Super-Galactic Jawbreaker (Stink, #2)'),
#  (4.0, 'Stepford Wives'),
#  (4.0,
#   'Stendhal: The Red and the Black and the Charterhouse of Parma (Modern Literatures in Perspective)'),
#  (4.0, 'Stark [The Dark Half]'),
#  ...]

# %% [markdown]
# After running our model, we see the top 10 users that are similar to Maureen's preferences using the Euclidean Distance. Also, we made a list of recommended books for "Maureen" based on the similarities of all other users to "Maureen", and their respective books that they rated, which "Maureen" has yet to rate them or read them.

# %% [markdown]
# # Answering the Questions

# %% [markdown]
# From the recommendations above, we see that the model was able to recommend books to a consumer that has yet to read or rate, based on similarities of other consumers and their respective book ratings.
#
# With these recommendations, we have created a model that can make predictions and recommend books to consumers.
#
# In addition, we also determined others consumers who has similar preferences to the original consumer and vice versa.
#
# Lastly, based on our model to make recommendations and determine interests of other consumers, we conclude that our model is able to effective help a retail book store improve their marketing strategies and inventory control which can potentially translate into higher sales and profits.

# %% [markdown]
# # Special Thanks

# %% [markdown]
# Special thanks to Samir Madhavan for inspiration on creating this project by applying it to real world data. Some of the earlier steps were similarly replicated from his book, Mastering Python for Data Science.
#
# ![Book Cover](files/book_cover.jpg)
